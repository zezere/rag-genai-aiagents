# %% [markdown]
# # Setup

# %%
# Import the userdata module from Google Colab
from google.colab import userdata
# Retrieve the API key stored under 'genai_course' from Colab's userdata
api_key = userdata.get('genai_course')

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change directory to this folder
# %cd /content/drive/MyDrive/GenAI/RAG/RAG with OpenAI

# %% [markdown]
# # Perform OCR and transform to images

# %%
# Install the pdf2image library for converting PDF files to images
# !pip install pdf2image
# Install the poppler-utils package, required by pdf2image to work with PDF files
# !apt-get install -y poppler-utils
# Out:
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pdf2image) (11.0.0)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.5 [186 kB]
# Fetched 186 kB in 1s (319 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 123633 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.5_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.5) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# Import the libraries
from pdf2image import convert_from_path
import os

# %%
# Function to converts pdfs into images and stores the image paths
def pdf_to_images(pdf_path, output_folder):
  # Create the output folder if it doesn't exist
  if not os.path.exists(output_folder):
    os.makedirs(output_folder)

  # Convert PDF into images
  images = convert_from_path(pdf_path) # Convert each page of the PDF to an image
  image_paths = []

  # Save images and store their paths
  for i, image in enumerate(images):
    image_path = os.path.join(output_folder, f"page{i+1}.jpg") # Generate the image file path
    image.save(image_path, "JPEG") # Save the image as a JPEG file
    image_paths.append(image_path) # Append the image path to the list

  return image_paths # Return the list of image paths

# %%
# Define the path to the PDF and the output folder for images
pdf_path = "Things mother used to make.pdf"
output_folder = "images"

# Convert the PDF into images and store the image paths
image_paths = pdf_to_images(pdf_path, output_folder)

# %%
# Install the openAI library
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)

# %%
# Import the libraries
from openai import OpenAI
import base64

# %%
# Set up connection to OpenAI API
client = OpenAI(
    api_key=api_key, # Use the provided API key for authentication
)
# Specify the model to be used
model = "gpt-4o-mini"

# %%
# Read and encode one image
image_path = "images/page23.jpg" # Path to the image to be encoded

# Encode the image in base64 and decode to string
with open(image_path, "rb") as image_file:
  image_data = base64.b64encode(image_file.read()).decode('utf-8')
image_data
# Out:
# '...'

# %%
# Define the system prompt
system_prompt = """
Please analyze the content of this image and extract any related recipe information.
"""

# %%
# Call the OpenAI API use the chat completion method
response = client.chat.completions.create(
    model = model,
    messages = [
        # Provide the system prompt
        {"role": "system", "content": system_prompt},

        # The user message contains both the text and image URL / path
        {"role": "user", "content": [
            "This is the imsage from the recipe page.",
            {"type": "image_url",
             "image_url": {"url": f"data:image/jpeg;base64,{image_data}",
                           "detail": "low"}}
        ]}
    ]
)

# %%
# Retrieve the content
gpt_response = response.choices[0].message.content

# %%
from IPython.display import Markdown, display

# Display the GPT response as Markdown
display(Markdown(gpt_response))

# %%
# Define a function to get the GPT response and display it in Markdown
def get_gpt_response():
  gpt_response = response.choices[0].message.content # Extract the response content from the API response
  return display(Markdown(gpt_response)) # Display the response as Markdown

# Call the function to display the GPT response
get_gpt_response()
# Out:
# Here are the recipes extracted from the image:
#
# ### Bannocks
# **Ingredients:**
# - 1 Cupful of Thick Sour Milk
# - ½ Cupful of Sugar
# - 2 Cupfuls of Flour
# - ½ Cupful of Indian Meal
# - 1 Teaspoonful of Soda
# - A pinch of Salt
#
# **Instructions:**
# 1. Make the mixture stiff enough to drop from a spoon.
# 2. Drop mixture, size of a walnut, into boiling fat.
# 3. Serve warm with maple syrup.
#
# ---
#
# ### Boston Brown Bread
# **Ingredients:**
# - 1 Cupful of Rye Meal
# - 1 Cupful of Sour Milk
# - 1 Cupful of Graham Meal
# - 1 Cupful of Molasses
# - 1 Cupful of Flour
# - ½ Teaspoonful of Indian Meal
# - 1 Cupful of Sweet Milk
# - 1 Heaping Teaspoonful of Soda
#
# **Instructions:**
# 1. Stir the meals and salt together.
# 2. Beat the soda into the molasses until it foams; add sour milk, mix well, and pour into a tin pan which has been well greased.
# 3. If you have no brown-bread steamer, bake in the oven.
#
# Feel free to let me know if you need any more help!

# %%
# Define improved system prompt
system_prompt2 = """
Please analyze the content of this image and extract any related recipe information into structure components.
Specifically, extra the recipe title, list of ingredients, step by step instructions, cuisine type, dish type, any relevant tags or metadata.
The output must be formatted in a way suited for embedding in a Retrieval Augmented Generation (RAG) system.
"""

# %%
# Call the api to extract the information
response = client.chat.completions.create(
    model = model,
    messages = [
        # Provide the system prompt
        {"role": "system", "content": system_prompt2},

         # The user message contains both the text and image URL / path
        {"role": "user", "content": [
            "This is the image from the recipe page",
            {"type": "image_url",
             "image_url": {"url": f"data:image/jpeg;base64,{image_data}",
                           "detail": "low"}}
        ]}
    ],
    temperature = 0, # Set the temperature to 0 for deterministic output
)

# %%
# Print the info from the page with the improved prompt
get_gpt_response()
# Out:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Breads
#
# ### Ingredients
# #### Bannocks
# - 1 Cupful of Thick Sour Milk
# - ½ Cupful of Sugar
# - 2 Cupfuls of Flour
# - ½ Cupful of Indian Meal
# - 1 Teaspoonful of Soda
# - A pinch of Salt
#
# #### Boston Brown Bread
# - 1 Cupful of Rye Meal
# - 1 Cupful of Graham Meal
# - 1 Cupful of Molasses
# - 1 Cupful of Flour
# - 1 Cupful of Sweet Milk
# - 1 Cupful of Sour Milk
# - ½ Teaspoonful of Salt
# - 1 Teaspoonful of Soda
# - 1 Heaping Teaspoonful of Baking Powder
#
# ### Step-by-Step Instructions
# #### Bannocks
# 1. Make the mixture stiff enough to drop from a spoon.
# 2. Drop mixture, size of a walnut, into boiling fat.
# 3. Serve warm, with maple syrup.
#
# #### Boston Brown Bread
# 1. Stir the meals and salt together.
# 2. Beat the soda into the molasses until it foams; add sour milk, mix well, and pour into a tin pan which has been well greased.
# 3. If you have no brown-bread steamer, use a regular oven.
#
# ### Cuisine Type
# Traditional American
#
# ### Dish Type
# Breads
#
# ### Relevant Tags/Metadata
# - Quick Bread
# - Breakfast
# - Comfort Food
# - Homemade
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.

# %%
# Extract information about all of the images/recipes
extracted_recipes = []

for image_path in image_paths:
  print(f"Processing image {image_path}")

  # Reading and decoding the image
  with open(image_path, "rb") as image_file:
    image_data = base64.b64encode(image_file.read()).decode("utf-8") # Encode the image to base64 format

  # Call the API to extract the information
  response = client.chat.completions.create(
      model = model,
      messages = [
          # Provide system prompt for guidance
          {"role": "system", "content": system_prompt2},

          # The user message contains both the text and image URL / path
          {"role": "user", "content": [
              "This is the image from the recipe page", # Context for the image
              {"type": "image_url",
              "image_url": {"url": f"data:image/jpeg;base64,{image_data}", # Provide the base64 image
                            "detail": "low"}}
          ]}
      ],
      temperature = 0, # Set the temperature to 0 for deterministic output
  )

  # Extract the content and store it
  gpt_response = response.choices[0].message.content # Get the response content
  extracted_recipes.append({"image_path": image_path, "recipe_info": gpt_response}) # Store the path and extracted info
  print(f"Extracted information for {image_path}:\n{gpt_response}\n") # Print the extracted information for review
# Out:
# Streaming output truncated to the last 5000 lines.
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Relevant Tags
# - Baking
# - Fruit Dessert
# - Traditional
#
# ---
#
# ### Recipe Title
# Quick Graham Bread
#
# ### Ingredients
# - 1 Pint of Graham Meal
# - 1 Cup of Soda
# - ½ Cup of Molasses
# - 1 Cup of Sour Milk
# - ½ Teaspoon of Salt
#
# ### Instructions
# 1. Stir the molasses, add sour milk and salt.
# 2. Mix well and sweeten with soda.
# 3. Bake thirty minutes or according to the heat of the oven. A moderate oven is best.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread
#
# ### Relevant Tags
# - Baking
# - Quick Bread
# - Traditional
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page28.jpg
# Extracted information for images/page28.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Graham Bread (raised over night)
#
# ### Ingredients
# - 3 Cupfuls of Graham Flour
# - 1 Tablespoonful of Lard
# - 3 Cupfuls of Warm Water
# - ½ Teaspoonful of Salt
# - 1 Tablespoonful of Sugar
# - 1 Package of Yeast
# - 1 Cupful of Milk (for Graham Muffins)
# - ½ Pint of White Flour (for Graham Muffins)
# - ½ Cupful of Molasses (for Graham Muffins)
# - ½ Teaspoonful of Salt (for Graham Muffins)
# - 2 Cupfuls of Sour Milk (for Sour Milk Griddle Cakes)
# - ½ Teaspoonful of Salt (for Sour Milk Griddle Cakes)
# - Soda (for Sour Milk Griddle Cakes)
#
# ### Step-by-Step Instructions
# 1. **Graham Bread:**
#    - Mix flour and lard together and rub in lard.
#    - Add yeast cake which has been dissolved in one-half cup of cold water.
#    - Mix with warm water at night.
#    - Set in a warm place to rise.
#    - In the morning, stir and let rise twice its bulk.
#    - Knead and put in baking pans. Let rise for about forty-five minutes.
#
# 2. **Graham Muffins:**
#    - Put the salt and soda into the molasses.
#    - Stir until blended and mix with milk or water.
#    - Drop into muffin tins and bake for twenty minutes.
#
# 3. **Sour Milk Griddle Cakes:**
#    - Stir the soda and salt into the milk and add enough flour to make thin batter.
#    - Cook on a well-greased griddle.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread, Muffins, Griddle Cakes
#
# ### Relevant Tags/Metadata
# - Baking
# - Yeast Bread
# - Breakfast
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page29.jpg
# Extracted information for images/page29.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Sweet Milk Griddle Cakes
#
# ### Ingredients
# - 1 Egg
# - 1 Pint of Sweet Milk
# - 2 Level Teaspoons of Cream of Tartar
# - 1 Level Teaspoon of Salt
# - Flour enough for thin batter
# - Butter (for serving)
# - Maple syrup (for serving)
#
# ### Instructions
# 1. Beat the egg.
# 2. Add milk and stir into flour.
# 3. Add cream of tartar.
# 4. Mix soda and cream of tartar in flour.
# 5. Fry in small cakes on a griddle.
# 6. Serve hot with butter and maple syrup.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Breakfast
#
# ### Relevant Tags
# - Pancakes
# - Griddle Cakes
# - Breakfast Recipes
# - Sweet Recipes
#
# ---
#
# ### Recipe Title
# Jenny Lind Tea Cake
#
# ### Ingredients
# - 1 Egg
# - ½ Cupful of Sugar
# - 1 Tablespoon of Melted Butter
# - Flour (enough to make a dry batter)
# - 1 Teaspoon of Salt
# - 1 Teaspoon of Cream of Tartar
#
# ### Instructions
# 1. Stir salt, egg, and sugar into the dry batter.
# 2. Add melted butter.
# 3. Mix in enough milk to make a batter as thick as cake.
# 4. Bake in a moderate oven.
# 5. Serve when done.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Relevant Tags
# - Tea Cakes
# - Dessert Recipes
# - Sweet Recipes
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page30.jpg
# Extracted information for images/page30.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Real Johnny Cake
#
# ### Ingredients
# - 2 Cups of Flour
# - 1 Cupful of Yellow Corn Meal
# - 1/2 Cupful of Sugar
# - 1/2 Teaspoonful of Salt
# - 1 Teaspoonful of Cream of Tartar
# - 1/2 Teaspoonful of Baking Powder
# - Enough milk or water to make a thin batter
#
# ### Step-by-Step Instructions
# 1. Combine flour, corn meal, sugar, and salt in a bowl.
# 2. In a separate bowl, mix cream of tartar and baking powder.
# 3. Add the dry ingredients to the wet mixture gradually.
# 4. Stir in enough milk or water to achieve a thin batter.
# 5. Bake in a moderate oven until done.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Baked Good
#
# ### Relevant Tags
# - Cornmeal
# - Breakfast
# - Traditional Recipe
#
# ---
#
# ### Recipe Title
# New England Buns
#
# ### Ingredients
# - 1 Cupful of Milk
# - 2 and 1/3 Cupfuls of Sugar
# - 1 Yeast Cake
# - 2 Cups of Flour (for dough)
# - 1 Teaspoonful of Soda
# - 1/2 Teaspoonful of Salt
# - 1/2 Teaspoonful of Extract of Lemon
# - 1/2 Cupful of Cold Water
#
# ### Step-by-Step Instructions
# 1. Dissolve the yeast in a half cup of cold water.
# 2. Scald the milk, then cool it to lukewarm.
# 3. Add sugar and flour to the milk, allowing it to rise twice.
# 4. When light and frothy, add the rest of the ingredients.
# 5. Mix in flour until the dough is manageable.
# 6. Cut with a cookie cutter and let rise again.
# 7. Bake in a moderate oven until golden.
#
# ### Cuisine Type
# New England
#
# ### Dish Type
# Bun
#
# ### Relevant Tags
# - Yeast Buns
# - Traditional Recipe
# - Breakfast
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page31.jpg
# Extracted information for images/page31.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Nut Bread and Oatmeal Bread
#
# ### Ingredients:
# #### Nut Bread:
# - 2½ Cups of Flour
# - 3 Teaspoons of Baking Powder
# - ¾ Cup of Milk
# - ½ Cup of Sugar
# - 1 Cup of Nuts, chopped
#
# #### Oatmeal Bread:
# - 2¾ Cups of Rolled Oats
# - 1½ Cups of Molasses
# - 1 Yeast Cake
# - Water
#
# ### Instructions:
# #### Nut Bread:
# 1. Mix flour, baking powder, and sugar together.
# 2. Add chopped nuts.
# 3. Stir in milk until well combined.
# 4. Pour into a greased loaf pan.
# 5. Bake for one hour.
#
# #### Oatmeal Bread:
# 1. Boil oats and water until cool.
# 2. Add molasses and yeast cake; stir until mixed.
# 3. Let the mixture sit until it rises.
# 4. Shape into a loaf and let rise again.
# 5. Bake for one hour.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Bread
#
# ### Tags/Metadata:
# - Baking
# - Quick Bread
# - Homemade Bread
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page32.jpg
# Extracted information for images/page32.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Parker House Rolls
#
# ### Ingredients
# - 1 Quart of Flour
# - 1 Tablespoon of Salt
# - ½ Pint of Milk
# - 3 Tablespoonfuls of Sugar
# - 1 Yeast Cake (or 1 packet of active dry yeast)
#
# ### Instructions
# 1. Scald the milk, which has been dissolved in one-half cup of cold water.
# 2. Rub the flour, salt, sugar, and yeast together in a bowl.
# 3. Mix in the scalded milk and knead.
# 4. Let rise to twice its bulk and knead again.
# 5. Roll half an inch thick, cut into rounds, and spread with butter and double over.
# 6. Rise again, and bake twenty minutes in a hot oven at ten o'clock in the morning if wanted for supper.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread/Rolls
#
# ### Relevant Tags
# - Yeast Rolls
# - Baking
# - Comfort Food
#
# ---
#
# ### Recipe Title
# Popovers
#
# ### Ingredients
# - 1 Egg
# - 1 Cupful of Milk
# - 1 Cupful of Flour
# - Salt to taste
#
# ### Instructions
# 1. Beat the egg and stir in the milk slowly, adding a little flour, then a little milk.
# 2. Salt to taste.
# 3. Mix to create a very thin batter.
# 4. Drop into a very hot oven in well-buttered muffin pans, and serve with hot sauce for a pudding, or eat with butter.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread/Pastry
#
# ### Relevant Tags
# - Quick Bread
# - Baking
# - Breakfast
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page33.jpg
# Extracted information for images/page33.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Rye Muffins
#
# ### Ingredients
# - 2 Cups of Flour
# - 1 Cupful of Rye Meal
# - 3 Tablespoons of Yeast Cake dissolved in Water
# - 1/2 Teaspoon of Salt
# - 1/4 Cupful of Boiling Water
#
# ### Instructions
# 1. Mix with warm water at night.
# 2. In the morning, add one-quarter teaspoonful of soda, dissolved in two tablespoonfuls of boiling water; stir well.
# 3. Bake in a greased pan for twenty or thirty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Muffins
#
# ### Relevant Tags
# - Breakfast
# - Baked Goods
# - Quick Bread
#
# ---
#
# ### Recipe Title
# Breakfast Sally Lunn
#
# ### Ingredients
# - 1 Egg
# - 2 Teacups of Milk
# - 1 Piece of Butter the size of an Egg
# - 4 Tablespoons of Sugar
# - 1/2 Teaspoon of Soda
# - 1/2 Teaspoon of Salt
# - 1 Cupful of Sour Milk
# - 1 Pint of Flour
#
# ### Instructions
# 1. Mix sugar, egg, and soda with the milk.
# 2. Beat the egg, stir into the melted butter and milk.
# 3. Stir all together and bake in a muffin pan, fifteen or twenty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Breakfast Dish
#
# ### Relevant Tags
# - Breakfast
# - Quick Bread
# - Baked Goods
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page34.jpg
# Extracted information for images/page34.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Spider Cake
#
# ### Ingredients:
# - 2 Cups of Bread Flour
# - 1 Teaspoonful of Soda
# - 1/3 Cup of Lard
# - 2 Teaspoonsful of Cream of Tartar
# - Salt (to taste)
#
# ### Step-by-Step Instructions:
# 1. Rub the lard and cream of tartar into the dry flour.
# 2. Roll the mixture into a soft dough.
# 3. Roll to the size of the spider or griddle.
# 4. When the spider is hot and well greased with lard, place the dough on the spider and cover.
# 5. Bake ten minutes on one side, then turn to the other side.
# 6. Bake ten minutes more without waiting for the bread to rise.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags/Metadata:
# - Baking
# - Traditional Recipe
# - Quick Bake
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page35.jpg
# Extracted information for images/page35.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Cakes - Filled Cookies
#
# ### Ingredients:
# #### For Filled Cookies:
# - 1 Cupful of Sugar
# - 1 Teaspoonful of Cream of Tartar
# - 1 Cupful of Butter or Lard
# - 1 Cupful of Milk
# - 3½ Cupfuls of Flour
# - 1 Tablespoonful of Vanilla
# - ½ Cupful of Chopped Raisins
# - ½ Cupful of Flour (for filling)
#
# #### For Sugar Cookies:
# - 1 Cupful of Sugar
# - 2 Teaspoons of Cream of Tartar
# - 2 Tablespoons of Soda
# - 1 Cupful of Milk
# - 1 Egg
# - Flour (enough to roll)
#
# ### Step-by-Step Instructions:
# 1. **For Filled Cookies:**
#    - Mix the sugar, butter (or lard), and milk together.
#    - Add the flour and vanilla, mixing until well combined.
#    - Prepare the filling by combining chopped raisins and flour.
#    - Roll out the dough and place a teaspoonful of filling on one side, fold over, and seal.
#    - Bake until lightly browned, being careful not to burn them.
#
# 2. **For Sugar Cookies:**
#    - Combine the butter, sugar, and egg together.
#    - Add the cream of tartar and soda, mixing well.
#    - Gradually add flour until the dough is manageable.
#    - Roll out the dough and cut into desired shapes.
#    - Bake until golden.
#
# ### Cuisine Type:
# Baking / Dessert
#
# ### Dish Type:
# Cookies
#
# ### Relevant Tags/Metadata:
# - Cookies
# - Baking
# - Sweet Treats
# - Filled Cookies
# - Sugar Cookies
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page36.jpg
# Extracted information for images/page36.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Cream Cake
#
# ### Ingredients:
# - 2 Cups of Flour
# - 1 Cupful of Cream of Tartar
# - 1 Teaspoon of Soda
# - 1 Cupful of Sugar
# - 2 Eggs
# - 1 Cupful of Cream
# - 1 Teaspoon of Flavoring (vanilla or almond)
#
# ### Step-by-Step Instructions:
# 1. Stir the flour, cream of tartar, and soda into the flour dry.
# 2. In a separate bowl, beat the eggs and sugar, salt, flour, and cream together.
# 3. Add the flavoring.
# 4. Mix all together and bake.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags/Metadata:
# - Cake
# - Baking
# - Sweet
# - Cream-based
#
# ---
#
# If you need any further modifications or additional information, feel free to ask!
#
# Processing image images/page37.jpg
# Extracted information for images/page37.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Old-time Gingersnaps
#
# ### Ingredients:
# - ½ Cupful of Molasses
# - ½ Cupful of Butter or Lard
# - 1 Teaspoonful of Soda
# - 1 Teaspoonful of Ginger
# - 1 Teaspoonful of Cinnamon
# - 1 Cupful of Sugar
# - 1 Egg
#
# ### Step-by-Step Instructions:
# 1. Boil the molasses for five minutes.
# 2. Remove from heat and add soda, butter, and ginger.
# 3. When cooled a little, stir in the sugar and egg.
# 4. Roll thin as a postage stamp.
# 5. Cut with a cooky-cutter and bake in a hot oven, being careful not to burn.
# 6. Shut in a tin pan. This recipe will keep for a long time.
#
# ### Cuisine Type:
# Traditional American
#
# ### Dish Type:
# Cookies
#
# ### Relevant Tags/Metadata:
# - Baking
# - Cookies
# - Traditional Recipes
# - Desserts
#
# ---
#
# ### Recipe Title:
# Gold Cake
#
# ### Ingredients:
# - 1 Cupful of Cream
# - ½ Cupful of Butter
# - 1 Cupful of Sugar
# - 4 Yolks of Eggs
# - 2 Cupsful of Flour
# - 1 Teaspoonful of Baking Powder
# - ½ Teaspoonful of Cream of Tartar
# - ½ Cupful of Milk
# - 1 Teaspoonful of Flavoring
# - Whites of 4 Eggs
#
# ### Step-by-Step Instructions:
# 1. Cream butter and sugar together.
# 2. Add the well-beaten eggs, then mix in the cream of tartar and soda.
# 3. Blend in the flour and milk into the mixture.
# 4. Bake until done.
#
# ### Cuisine Type:
# Traditional American
#
# ### Dish Type:
# Cake
#
# ### Relevant Tags/Metadata:
# - Baking
# - Cakes
# - Traditional Recipes
# - Desserts
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page38.jpg
# Extracted information for images/page38.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# - Hermits
#
# ### Ingredients
# - ½ Cup of Molasses
# - ⅔ Cup of Butter
# - 2 Eggs
# - 1 Cup of Raisins
# - 2 Tablespoons of Milk
# - 1 Teaspoon of Soda
# - 1 Teaspoon of Nutmeg
# - ½ Teaspoon of Cloves
# - Flour enough to roll
#
# ### Instructions
# 1. Cream the butter and sugar together.
# 2. Beat the eggs, add to the butter and sugar, then stir in the molasses, mixing well.
# 3. Add the raisins and spices.
# 4. Roll the dough into which the dry soda has been sifted.
# 5. Roll thin and cut with cookie-cutter.
#
# ### Cuisine Type
# - American
#
# ### Dish Type
# - Dessert
#
# ### Relevant Tags
# - Cookies
# - Baking
# - Traditional Recipes
#
# ---
#
# ### Recipe Title
# - Jumbles
#
# ### Ingredients
# - 2 Cups of Sugar
# - ½ Cup of Butter
# - 1 Egg
# - ½ Cup of Milk
# - 1 Teaspoon of Cream of Tartar
# - 1 Teaspoon of Lemon Extract
# - 1 Teaspoon of Soda
# - Flour enough to roll
#
# ### Instructions
# 1. Cream together the butter and sugar.
# 2. Add the beaten egg.
# 3. Add milk, cream of tartar, and soda into the mixture.
# 4. Roll into rings and bake in a well-greased pan.
#
# ### Cuisine Type
# - American
#
# ### Dish Type
# - Dessert
#
# ### Relevant Tags
# - Cookies
# - Baking
# - Traditional Recipes
#
# Processing image images/page39.jpg
# Extracted information for images/page39.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Nut Cake and Oatmeal Cookies
#
# ### Ingredients
#
# #### Nut Cake
# - 1 Cup of Sugar
# - 1 Cupful of Butter
# - 2 Eggs
# - 2 Cupfuls of Flour
# - 1 Teaspoon of Cream of Tartar
# - 1 Teaspoon of Baking Soda
# - 1 Cupful of Hickory Nut Meats or English Walnuts
#
# #### Oatmeal Cookies
# - 2 Eggs
# - 1 Cupful of Sugar
# - 1½ Cupfuls of Oatmeal or Rolled Oats
# - 1 Cupful of Coconut
# - ½ Teaspoon of Salt
# - 1 Teaspoon of Vanilla
# - 2 Tablespoons of Butter
#
# ### Instructions
#
# #### Nut Cake
# 1. Cream the butter and sugar together.
# 2. Then add the eggs and milk, and put in the cream of tartar into the flour.
# 3. Stir all together, adding nut meats.
#
# #### Oatmeal Cookies
# 1. Cream the butter and sugar together and add the well-beaten eggs.
# 2. Add the remainder of the ingredients and drop onto a well-greased baking pan.
# 3. Bake in a moderate oven for fifteen to twenty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Tags/Metadata
# - Baking
# - Cakes
# - Cookies
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page40.jpg
# Extracted information for images/page40.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# One, Two, Three, Four Cake
#
# ### Ingredients
# - 1 Cupful of Butter
# - 2 Cupfuls of Sugar
# - 2 Cupfuls of Flour
# - 2 Teaspoons of Cream of Tartar
# - 1 Teaspoon of Soda
# - 2/3 Cupful of Milk
# - 3 Eggs
#
# ### Step-by-Step Instructions
# 1. Cream the butter and sugar together and add the well-beaten eggs; beat all together.
# 2. Put in the cream of tartar and the soda into the flour; stir all together.
# 3. Bake in a slow oven. This will make two loaves.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Cake
#
# ### Relevant Tags
# - Baking
# - Dessert
# - Classic Recipes
#
# ---
#
# ### Recipe Title
# Ribbon Cake
#
# ### Ingredients
# - 3 Eggs
# - 1/2 Salt and flavor
# - 2 Cupfuls of Sugar
# - 1 Cupful of Milk
# - 3 Cupfuls of Flour
# - 1 Teaspoonful of Cream
# - 1 Tablespoonful of Molasses
# - 2/3 Cupful of Almond or Vanilla
# - 1/2 Pound of Cinnamon
# - 1/2 Nutmeg
#
# ### Step-by-Step Instructions
# 1. Beat the eggs and sugar together.
# 2. Add the milk, salt, and soda, and cream of tartar, mixing all together.
# 3. Pour half of this mixture into two oblong pans.
# 4. In the remaining half, add one large cupful of raisins, stoned and chopped.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Cake
#
# ### Relevant Tags
# - Baking
# - Dessert
# - Classic Recipes
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page41.jpg
# Extracted information for images/page41.jpg:
# Here’s the structured information extracted from the recipe page:
#
# ### Recipe Title:
# Roll Jelly Cake
#
# ### Ingredients:
# - 4 Eggs
# - 1/2 Cup of Sugar
# - 1 Cup of Flour
# - 1/2 Teaspoon of Salt
# - 1 Cup of Sugar (for filling)
# - 1 Teaspoon of Extract (vanilla or other)
# - 1/2 Teaspoon of Cream of Tartar
#
# ### Instructions:
# 1. Beat together the eggs and sugar.
# 2. Add the flour and salt, mixing well.
# 3. Stir in the extract and cream of tartar.
# 4. Spread the mixture evenly in a greased pan.
# 5. Bake in a moderate oven until lightly browned.
# 6. Remove from the oven, turn out onto a clean towel, and sprinkle with powdered sugar.
# 7. Roll the cake up with the towel while warm, alternating with jelly in between.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags/Metadata:
# - Cake
# - Jelly Roll
# - Baking
# - Sweet Treat
#
# ---
#
# ### Recipe Title:
# Silver Cake
#
# ### Ingredients:
# - 1 Cup of Sugar
# - 1 Cup of Milk
# - 2 Cups of Flour
# - 1/3 Cup of Butter
# - 3 Eggs
# - 1 Scant Teaspoon of Baking Powder
# - 1/2 Teaspoon of Almond Flavoring
#
# ### Instructions:
# 1. Cream together the butter and sugar.
# 2. Add milk and mix into the batter.
# 3. Last, add all the other ingredients and mix well.
# 4. Pour into a greased pan and bake until done.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Cake
#
# ### Relevant Tags/Metadata:
# - Cake
# - Baking
# - Sweet Treat
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page42.jpg
# Extracted information for images/page42.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Sponge Cake
#
# ### Ingredients
# **Sponge Cake, No. 1:**
# - 3 Eggs
# - 1½ Cupfuls of Flour
# - 1½ Cupfuls of Sugar
# - ½ Cupful of Water
# - Pinch of Salt
# - 1 Teaspoonful of Cream of Tartar
# - ½ Teaspoonful of Soda
#
# **Sponge Cake, No. 2, Grandmother's Rule:**
# - 4 Eggs
# - 1 Cupful of Sugar
# - 1 Cupful of Flour
# - 1 Teaspoonful of Baking Powder
#
# ### Instructions
# 1. Beat eggs and sugar together, add water and salt, then put soda and cream of tartar into the dry flour. Beat all together. Bake slowly.
# 2. For the second recipe, beat the eggs ten minutes, add sugar, and beat again. Then add the flour, stir all together and bake in a moderate oven.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Tags/Metadata
# - Cake
# - Baking
# - Sponge Cake
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page43.jpg
# Extracted information for images/page43.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Old-Fashioned Candies
#
# ### Ingredients
# #### Chocolate Taffy
# - 1½ Cups of Molasses
# - 1½ Cups of Sugar
# - ½ Cup of Milk
# - 2 Squares of Chocolate
# - 1 Small Teaspoon of Flour
# - Butter (for greasing)
#
# #### Molasses Candy
# - 2 Cups of Molasses
# - ¼ Teaspoon of Soda
# - 2 Teaspoons of Vinegar
# - Butter (for greasing)
#
# ### Instructions
# #### Chocolate Taffy
# 1. Stir the sugar, flour, and grated chocolate into the molasses and milk.
# 2. When hot, add the butter. Boil until it strings.
# 3. Pour into buttered tin. When nearly cold, mark into squares.
#
# #### Molasses Candy
# 1. Put the molasses, vinegar, and butter into a saucepan.
# 2. Boil until it strings when dropped from a spoon.
# 3. When it is brittle when tested in cold water, stir the soda in briskly and pour into a buttered tin.
# 4. When nearly cold, cut into small pieces or sticks and lay on a buttered platter.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Candy
#
# ### Tags/Metadata
# - Old-fashioned
# - Candy recipes
# - Sweet treats
# - Homemade candy
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page44.jpg
# Extracted information for images/page44.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Butter Scotch
#
# ### Ingredients
# - ½ Cup of Molasses
# - ½ Cup of Butter
# - ½ Cup of Sugar
#
# ### Instructions
# 1. Boil the ingredients until it strings.
# 2. Pour into buttered tin and let cool.
# 3. When cool, break into pieces.
#
# ### Cuisine Type
# Dessert
#
# ### Dish Type
# Candy
#
# ### Relevant Tags
# - Sweet
# - Confectionery
# - Traditional Recipe
#
# ---
#
# ### Recipe Title
# Pop Corn Balls (very old recipe)
#
# ### Ingredients
# - 1 Cup of Molasses
# - Piece of Butter, half the size of an Egg
#
# ### Instructions
# 1. Boil together until it strings and then stir in a pinch of soda.
# 2. Put this over a quart dish and cool.
# 3. When cool enough to handle, squeeze into balls the size of an orange.
#
# ### Cuisine Type
# Snack
#
# ### Dish Type
# Candy
#
# ### Relevant Tags
# - Sweet
# - Snack
# - Traditional Recipe
#
# Processing image images/page45.jpg
# Extracted information for images/page45.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Apple Tarts
#
# ### Ingredients:
# - Pie crust
# - Apples
# - Sugar
# - Egg whites
#
# ### Step-by-Step Instructions:
# 1. Roll pie crust thin as for pies.
# 2. Cut into rounds, pinching up the edge half an inch high and place in muffin rings.
# 3. Put into each one a tablespoon of apple sauce and bake in a hot oven for twenty minutes.
# 4. Beat the egg whites of two eggs to a stiff froth and add two tablespoons of sugar.
# 5. Drop a spoonful on the top of each and brown quickly in a hot oven.
#
# ### Cuisine Type:
# Dessert
#
# ### Dish Type:
# Tart
#
# ### Relevant Tags/Metadata:
# - Desserts
# - Baked Goods
# - Fruit-based Desserts
#
# ---
#
# ### Recipe Title:
# Baked Apples, No. 1
#
# ### Ingredients:
# - Apples
# - Sugar
# - Cream (optional)
#
# ### Step-by-Step Instructions:
# 1. Take good, sour apples; greenings are best.
# 2. Scoop out the cores, wash and place in a baking pan.
# 3. Fill the hole with sugar and a tablespoon of butter for each apple beside.
# 4. Pour over these a generous supply of cream.
# 5. Bake in a hot oven until light and fluffy.
# 6. Serve this as a delicious dessert, if served with cold cream.
#
# ### Cuisine Type:
# Dessert
#
# ### Dish Type:
# Baked Fruit
#
# ### Relevant Tags/Metadata:
# - Desserts
# - Baked Goods
# - Fruit-based Desserts
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page46.jpg
# Extracted information for images/page46.jpg:
# Here’s the structured information extracted from the recipe page:
#
# ### Recipe Title:
# Baked Sweet Apples
#
# ### Ingredients:
# - 6 apples
# - Molasses (to taste)
# - Sugar (optional, to taste)
# - Milk (for serving)
#
# ### Instructions:
# 1. Wash clean, pare, and slice the apples.
# 2. Put the apples into a baking pan with a little cold water.
# 3. Add molasses, if desired.
# 4. Bake for three to four hours until they are a dark amber color.
# 5. Serve with crackers and milk.
#
# ---
#
# ### Recipe Title:
# Apple Dumplings
#
# ### Ingredients:
# - Pie crust
# - Apples (as many as needed)
# - Sugar (for sprinkling)
# - Butter (for topping)
# - Cold water (for sealing)
#
# ### Instructions:
# 1. Take the pie crust, roll thin for pie and cut into rounds as large as a tea saucer.
# 2. Pare and slice fine the apples for each dumpling.
# 3. Lay the apple slices on the crust, sprinkle with sugar, and dot with butter.
# 4. Fold the crust edges over the apple and press together.
# 5. Bake in a hot oven for twenty minutes. Serve hot with cold sauce.
#
# ---
#
# ### Recipe Title:
# Fried Apples
#
# ### Ingredients:
# - Apples (as many as needed)
# - Butter (for frying)
# - Sugar (optional, to taste)
#
# ### Instructions:
# 1. Pare and slice apples.
# 2. Fry in hot fat until tender.
# 3. Remove from the fire and sprinkle with sugar if desired.
#
# ---
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags:
# - Apples
# - Baking
# - Dumplings
# - Fried Desserts
# - Traditional Recipes
#
# Processing image images/page47.jpg
# Extracted information for images/page47.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Bramberries
#
# ### Ingredients
# **Crust:**
# - 1½ Cups of Flour
# - ½ Cup of Lard
# - ½ Teaspoon of Salt
# - Just enough Water to wet smooth
#
# **Filling:**
# - 1 Cup of Raisins
# - 1 Cracker
# - ½ Cup of Sugar
# - 2/3 Cup of Sugar (for filling)
# - 1 Egg
# - A Little Salt
#
# ### Instructions
# 1. Beat the egg, add sugar, salt, lemon juice, and grated rind.
# 2. Roll cracker fine, chop raisins and mix all together.
# 3. Roll the crust thin to ¼ inch thick.
# 4. Put a spoonful of filling into the crust.
# 5. Shape into desired form and prick top with fork.
# 6. Bake in iron pan for twenty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Tags/Metadata
# - Sweet
# - Baked
# - Fruit-based
# - Traditional
#
# ---
#
# ### Recipe Title
# Cream Puffs
#
# ### Ingredients
# - 1 Cup of Hot Water
# - ½ Cup of Flour
# - 1 Pinch of Salt
# - 1 Teaspoon of Baking Soda
# - 5 Eggs
#
# ### Instructions
# 1. In a dish, combine hot water, flour, and salt.
# 2. Stir in the baking soda.
# 3. When the mixture is cool, add eggs one at a time.
# 4. Drop onto a buttered pan and bake for twenty minutes at a hot oven.
# 5. When done, make a slit in the side with a knife.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Pastry
#
# ### Tags/Metadata
# - Savory
# - Baked
# - Light
# - Traditional
#
# Processing image images/page48.jpg
# Extracted information for images/page48.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Floating Island
#
# ### Ingredients:
# - 1 Quart of Milk
# - 4 Eggs
# - 1 Cupful of Sugar
# - 1 Teaspoon of Cornstarch
# - 1 Teaspoon of Vanilla
# - Pinch of Salt
# - 1 Lemon (for flavor)
#
# ### Step-by-Step Instructions:
# 1. Put the milk on the stove and heat to nearly boiling point.
# 2. In a separate bowl, beat the eggs, sugar, flour, and a little salt together until smooth.
# 3. Stir the egg mixture into the boiling milk.
# 4. Flavor with lemon.
# 5. Cook until it boils, then remove from heat.
# 6. Serve cold, with the "islands" on top of the custard.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags/Metadata:
# - Custard
# - Egg-based dessert
# - Classic recipe
# - Comfort food
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page49.jpg
# Extracted information for images/page49.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# - Coffee Jelly
#
# ### Ingredients
# - 1 Small Box of Gelatine
# - 1 Pint of Strong Coffee
# - 1 Cupful of Sugar
# - 1 Scent Quart of Boiling Water
# - Flavor with Vanilla
#
# ### Instructions
# 1. Soak the gelatine in cold water for fifteen minutes.
# 2. Stir into the coffee and add sugar and water, then vanilla.
# 3. Pour into a mold and set away to cool.
# 4. Serve with sweetened whipped cream.
#
# ### Cuisine Type
# - American
#
# ### Dish Type
# - Dessert
#
# ### Relevant Tags
# - Gelatin Dessert
# - Coffee Flavored
# - Sweet Treat
#
# ---
#
# ### Recipe Title
# - Lemon Jelly
#
# ### Ingredients
# - 1½ Box of Gelatine
# - 1 Cupful of Sugar
# - 3 Lemons
# - 1 Cupful of Cold Water
# - 2 Quarts of Boiling Water
#
# ### Instructions
# 1. Soak gelatine in the cold water for half an hour.
# 2. Add boiling water, sugar, and juice of lemons.
# 3. Stir well and strain into mold or small cups.
#
# ### Cuisine Type
# - American
#
# ### Dish Type
# - Dessert
#
# ### Relevant Tags
# - Gelatin Dessert
# - Lemon Flavored
# - Sweet Treat
#
# Processing image images/page50.jpg
# Extracted information for images/page50.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Strawberry Shortcake
#
# ### Ingredients
# **For the first recipe:**
# - 1 Pint of Flour
# - ⅓ Cupful of Lard
# - 1 Teaspoon of Soda
# - 1 Teaspoon of Cream of Tartar
# - Milk (enough to make a stiff dough)
# - 2 Cupfuls of Cream
# - 2 Cupfuls of Strawberries
#
# **For the second recipe:**
# - 1 Tablespoon of Butter
# - ½ Cupful of Milk
# - ½ Cupful of Strawberries
# - 1 Teaspoon of Soda
# - ½ Teaspoon of Cream of Tartar
# - 1 Cup of Cream
#
# ### Step-by-Step Instructions
# 1. For the first recipe, mix the flour, lard, soda, and cream of tartar into the dry flour.
# 2. Add milk gradually to form a stiff dough.
# 3. Roll out the dough, cut into shapes, and bake for twenty minutes.
# 4. For the second recipe, cream together the butter and egg.
# 5. Add the well-beaten egg and milk to the mixture.
# 6. Combine with the dry ingredients (flour, soda, cream of tartar).
# 7. Bake in a well-greased pan.
# 8. After baking, wash and sweeten the strawberries.
# 9. Put half of the strawberries between the two cakes, butter, and place the other half on top.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Dessert
#
# ### Relevant Tags/Metadata
# - Strawberry Shortcake
# - Baking
# - Summer Dessert
# - Fresh Strawberries
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page51.jpg
# Extracted information for images/page51.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title:
# Eggs
#
# ### Ingredients:
# - Eggs
# - Salt (for boiling)
# - Bread (for toast)
# - Butter
# - Pepper (optional)
#
# ### Step-by-Step Instructions:
# 1. **To Boil Eggs:**
#    - Put your eggs into a bowl that can be sent to the table.
#    - Pour boiling water over them and let stand for 8 to 10 minutes.
#    - Ensure the water is boiling.
#    - Note: Eggs should never be boiled in any other way for invalids.
#
# 2. **Eggs on Toast:**
#    - Toast as many slices of bread as desired.
#    - Butter and pour over the toasted slices just enough salted water to soften.
#    - Prepare a dish of boiling water.
#    - Stir round and mix with a spoon, break the egg and drop into the swirling water.
#    - Remove from the water in four to six minutes, as preferred, and place on one each slice of bread.
#    - Serve hot with a dash of pepper, if liked.
#
# ### Cuisine Type:
# General
#
# ### Dish Type:
# Breakfast
#
# ### Relevant Tags/Metadata:
# - Boiling
# - Toasting
# - Quick Meal
# - Breakfast Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page52.jpg
# Extracted information for images/page52.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Plain Omelette
#
# ### Ingredients
# - 2 Eggs
# - Pinch of Salt
# - 2 Spoonfuls of Water
#
# ### Instructions
# 1. Beat the eggs and yolks separately.
# 2. Add salt and water.
# 3. Pour into a hot frying pan and fry until it is puffed up.
# 4. Turn half over and serve at once.
#
# ---
#
# ### Recipe Title
# Ham Omelette
#
# ### Ingredients
# - 2 Eggs
# - Chopped boiled ham (about two-thirds of a cup)
#
# ### Instructions
# 1. Make a plain omelette.
# 2. Pour in the chopped ham.
# 3. Cook both sides.
#
# ---
#
# ### Recipe Title
# New England Poached Eggs
#
# ### Ingredients
# - 4 Eggs
# - 8 Tablespoons of Milk
# - Butter (size of a walnut)
# - ½ Teaspoon of Salt
#
# ### Instructions
# 1. Break the eggs into a sauce pan with milk, salt, and butter.
# 2. Cook until they thicken, stirring constantly.
# 3. Serve hot with a dash of pepper.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Breakfast
#
# ### Tags
# - Omelette
# - Poached Eggs
# - Breakfast Recipes
# - Easy Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page53.jpg
# Extracted information for images/page53.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Clam Fritters
#
# ### Ingredients:
# - 1 Egg
# - 1 Cupful of Milk
# - 1 Cupful of Bread-flour and a little extra
# - Salt (to taste)
# - 1 Cupful of Hot Mashed Potatoes
# - ½ Cupful of Shredded Cod-fish
# - 2 Teaspoons of Melted Butter
#
# ### Step-by-Step Instructions:
# 1. Beat the egg and half the milk, adding the flour gradually to make the batter smooth. Add salt to taste.
# 2. Add the last half-cupful of milk. Put one teaspoonful of butter and drop into boiling lard. Serve hot.
# 3. For the fish balls, put the fish into a piece of cheese-cloth, let cold water run over it, and squeeze out the water.
# 4. Mix all ingredients together: mashed potatoes, shredded cod-fish, and melted butter.
# 5. Take a little flour in the hand and roll into balls, to the size of a small peach. Fry in deep fat.
#
# ### Cuisine Type:
# Seafood
#
# ### Dish Type:
# Appetizer
#
# ### Relevant Tags/Metadata:
# - Clam Fritters
# - Seafood Recipe
# - Frying
# - Comfort Food
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page54.jpg
# Extracted information for images/page54.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Baked Mackerel
#
# ### Ingredients:
# - 1 Mackerel
# - 3 Small Slices of Salt Pork
# - Salt to Taste
#
# ### Instructions:
# 1. Split open the mackerel and remove the insides.
# 2. Wash clean and lay in a baking-pan on a buttered paper or cheese-cloth.
# 3. Place the slices of salt pork on top of the mackerel.
# 4. Season with salt to taste.
#
# ### Cuisine Type:
# Seafood
#
# ### Dish Type:
# Main Course
#
# ### Tags/Metadata:
# - Mackerel
# - Baking
# - Seafood Recipe
# - Simple Ingredients
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page55.jpg
# Extracted information for images/page55.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Oysters on Toast
#
# ### Ingredients:
# - Oysters
# - Bread (slices)
# - Salt
# - White sauce (for serving)
#
# ### Instructions:
# 1. Toast as many slices of bread as required.
# 2. Wipe enough oysters to cover them and season with pepper and salt.
# 3. Place the hot, toasted bread on a plate, allowing the edges to remain visible.
# 4. Serve hot with a white sauce.
#
# ---
#
# ### Recipe Title:
# Baked Shad
#
# ### Ingredients:
# - Dressing (made of five or six crackers, bread crumbs)
# - Poultry dressing (optional)
# - Salt
# - Small piece of fish (shad)
# - Water (for soaking)
# - Paper (for wrapping)
# - Cheesecloth (for baking)
#
# ### Instructions:
# 1. Make a nice dressing using crackers or bread crumbs.
# 2. Roll the fish in the dressing and soak in water.
# 3. Season to taste with salt and add a small piece of fish.
# 4. Wash the shad and stuff it.
# 5. Wrap in a large sheet of white paper, well buttered, or in cheesecloth.
# 6. Place into a baking pan and bake in the same way as other fish.
#
# ### Cuisine Type:
# Traditional/Classic
#
# ### Dish Type:
# Seafood
#
# ### Relevant Tags:
# - Oysters
# - Toast
# - Baked Fish
# - Classic Recipes
# - Seafood Dishes
#
# Processing image images/page56.jpg
# Extracted information for images/page56.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# A La Mode Beef
#
# ### Ingredients
# - 3 Pounds of Beef
# - 6 Onions
# - 4 or 5 White Turnips
# - Potatoes
# - Salt
#
# ### Instructions
# 1. Take three pounds of a cheap cut of beef. Wash, put into an iron pan, and sprinkle over it salt to taste.
# 2. Pare six onions and, if necessary, pare four or five small turnips sliced thin. Lay these around the meat and cover the whole quart of cold water.
# 3. Put into the oven and bake three hours. Pare potatoes enough for the serving, putting them in an hour and a half before serving.
# 4. This is a most delicious way to cook beef. As the water cooks away, add more. Thicken the gravy with your roast meat.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Meat Dish
#
# ### Tags/Metadata
# - Comfort Food
# - Slow Cook
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page57.jpg
# Extracted information for images/page57.jpg:
# Here’s the structured information extracted from the recipe:
#
# ### Recipe Title
# Beef Stew with Dumplings
#
# ### Ingredients
#
# #### For Beef Stew
# - 3 pounds of beef (with meat)
# - 2 large onions
# - 4 potatoes
# - 1 tablespoon of salt
# - Water (as needed)
#
# #### For Dumplings
# - 2 heaping cups of flour
# - 1 teaspoon of baking soda
# - ½ teaspoon of cream of tartar
# - 1 glass of water
#
# ### Step-by-Step Instructions
#
# #### Beef Stew
# 1. Wash the meat and place it in a kettle with cold water.
# 2. Bring to a boil, then reduce heat and allow to simmer.
# 3. Prepare the onions and wash, slice, and add them to the kettle.
# 4. Add potatoes, wash, slice, and put them in with the beef.
# 5. Allow the stew to cook for three hours.
#
# #### Dumplings
# 1. In a bowl, mix the flour, baking soda, and cream of tartar.
# 2. Add water gradually to form a dough.
# 3. Roll out the dough on a plate, cut into pieces, and place on top of the meat in the stew.
# 4. Cover and let cook for an additional twenty minutes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Main Course
#
# ### Tags/Metadata
# - Comfort Food
# - Hearty Meal
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page58.jpg
# Extracted information for images/page58.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# New England Boiled Dinner
#
# ### Ingredients
# - Corned beef
# - White and sweet potatoes
# - Cabbage
# - Beets
# - Turnips
# - Squash
# - Parsnips
# - Carrots
# - Salt
# - Pepper
#
# ### Step-by-Step Instructions
# 1. Boil the corned beef for four hours.
# 2. After four hours, add the cabbage and one hour's worth of beets, carrots, and parsnips.
# 3. Boil these in one pot.
# 4. Prepare the potatoes by peeling and slicing them.
# 5. Pick out the vegetables from the cabbage and cut them into quarters.
# 6. Drop the beets into cold water and slice the skin off.
#
# ### Cuisine Type
# New England
#
# ### Dish Type
# Main Course
#
# ### Relevant Tags/Metadata
# - Boiled Dinner
# - Comfort Food
# - Traditional Recipe
#
# ---
#
# ### Recipe Title
# Brunswick Stew
#
# ### Ingredients
# - Chicken or 3 pounds of lamb
# - 4 ears of corn
# - Salt and pepper
# - Tomatoes (from the can)
# - Onions (all chopped)
#
# ### Step-by-Step Instructions
# 1. Cook the chicken or lamb until tender.
# 2. Take from the water and cool.
# 3. Pick the meat from the bones.
# 4. Put the meat back in the liquid along with the corn, tomatoes, and onions.
#
# ### Cuisine Type
# Southern
#
# ### Dish Type
# Stew
#
# ### Relevant Tags/Metadata
# - Comfort Food
# - Traditional Recipe
# - Southern Cuisine
#
# Processing image images/page59.jpg
# Extracted information for images/page59.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# How to Corn Beef
#
# ### Ingredients:
# - Fresh beef (piece weighing seven or eight pounds)
# - Corn (for corning)
# - Tomatoes (optional)
# - Salt
# - Pepper
# - Milk
# - Potatoes
# - Lump of butter
#
# ### Step-by-Step Instructions:
# 1. Clean and put the beef in an earthen dish, covering it with corn and tomatoes before cooking.
# 2. Cook the beef for four hours.
# 3. For the corned beef:
#    - Prepare the potatoes by peeling and cutting them into small pieces.
#    - Put them in a saucepan or a large kettle.
#    - Add a small amount of water, an egg, and a few spoonfuls of milk.
#    - Season with salt and pepper to taste.
#    - Loosen the mixture with a little milk and turn on the heat.
#    - Cook until the potatoes are tender.
# 4. Serve with a lump of butter.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Main Course
#
# ### Relevant Tags/Metadata:
# - Corned Beef
# - Comfort Food
# - Traditional Recipe
# - Family Meal
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page60.jpg
# Extracted information for images/page60.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Breaded Pork Chops
#
# ### Ingredients
# - 6 Pork Chops
# - 1 Cup of Bread Crumbs
# - 1 Egg
# - ½ Cup of Milk
# - Pinch of Salt
#
# ### Instructions
# 1. Beat the egg and milk together.
# 2. Dip the pork chops into the mixture.
# 3. Coat with bread crumbs.
# 4. Fry in hot fat until cooked.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Main Course
#
# ### Relevant Tags
# - Pork
# - Breaded
# - Fried
# - Comfort Food
#
# ---
#
# ### Recipe Title
# Potted Beef
#
# ### Ingredients
# - 3 Pounds of a Cheap Cut of Beef
# - ½ Can of Tomatoes
# - Salt to taste
# - Onions
#
# ### Instructions
# 1. Put the meat into a kettle, cover with cold water, and boil slowly for two hours.
# 2. Add salt and onions, and continue to boil all together.
# 3. Add water as needed.
# 4. Serve the meat hot.
# 5. The liquor makes a delicious soup, thickened with two potatoes.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Main Course
#
# ### Relevant Tags
# - Beef
# - Stew
# - Comfort Food
#
# ---
#
# ### Recipe Title
# A Fine Way to Cook Veal
#
# ### Ingredients
# - 2 Pounds of Veal
# - 1 Egg
# - ½ Cup of Milk
# - Salt and Pepper to taste
#
# ### Instructions
# 1. Cut the veal into small pieces.
# 2. Season with salt and pepper.
# 3. Fry until cooked.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Main Course
#
# ### Relevant Tags
# - Veal
# - Fried
# - Comfort Food
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page61.jpg
# Extracted information for images/page61.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Veal Patties
#
# ### Ingredients:
# - 1½ Cupfuls of Boiled Rice
# - 1 Cupful of Veal
# - 1 Egg
# - 1 Tablespoon of Milk
# - ½ Teaspoon of Poultry Seasoning
# - Salt (to taste)
# - Lard (for frying)
#
# ### Instructions:
# 1. Grind or chop the veal, salt, and stir into the rice with the eggs, milk, and poultry seasoning.
# 2. Mix all ingredients thoroughly.
# 3. Drop a tablespoonful of the mixture onto a hot griddle.
# 4. Fry until golden brown on both sides.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Main Course
#
# ### Tags/Metadata:
# - Comfort Food
# - Traditional Recipe
# - Meat Dish
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page62.jpg
# Extracted information for images/page62.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Boston Baked Beans
#
# ### Ingredients:
# - Three cups of small white beans
# - Water (for soaking and boiling)
# - 8 teaspoons of sugar
# - 1 teaspoon of salt
# - 1/2 pound of salt pork (or an alternative)
#
# ### Instructions:
# 1. Pick over and wash three cups of small white beans.
# 2. Cover with cold water and soak overnight.
# 3. In the morning, put them on the stove in just enough water to cover.
# 4. Do not boil; pour off the water and put into an earthen bean pot.
# 5. Add eight teaspoons of sugar, one teaspoon of salt, and half a pound of salt pork.
# 6. Cover with water and bake from eight A.M. until six P.M.
# 7. As the water boils away, add more.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Main Dish
#
# ### Tags/Metadata:
# - Beans
# - Baked
# - Traditional
# - Comfort Food
#
# ---
#
# ### Recipe Title:
# A Breakfast Dish
#
# ### Ingredients:
# - Four Boston crackers
# - Butter (for toasting)
# - A delicate brown (sugar or syrup) to pour over
#
# ### Instructions:
# 1. Take four Boston crackers, split open, and toast to a delicate brown on each side.
# 2. Put these into a bowl or earthen dish of some kind.
# 3. Pour over the delicate brown.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Breakfast
#
# ### Tags/Metadata:
# - Breakfast
# - Quick
# - Easy
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page63.jpg
# Extracted information for images/page63.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Grape Juice
#
# ### Ingredients:
# - 3 Pounds of Grapes
# - 1 Cupful of Water
#
# ### Instructions:
# 1. Pick from the stems and wash clean, ten pounds of grapes.
# 2. Put them on the stove in a kettle, with a little water, and cook until tender.
# 3. Strain through a flannel bag.
# 4. Return juice to the kettle, add sugar, and boil for five minutes.
# 5. Seal in glass jars when boiling hot. Slant the jars when filling to prevent cracking.
# 6. When serving, add nearly the same amount of water.
#
# ### Cuisine Type:
# Not specified
#
# ### Dish Type:
# Beverage
#
# ### Tags/Metadata:
# - Homemade
# - Juice
# - Grape
# - Preservation
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page64.jpg
# Extracted information for images/page64.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Minced Meat
#
# ### Ingredients
# - 4 Cupfuls of Chopped Meat
# - 12 Cupfuls of Chopped Vegetables
# - 2 Cupfuls of Vinegar
# - 5 Cupfuls Seeded Raisins
# - 1 Cupful of Currants
# - 5 Cupfuls of Brown Sugar
# - 1½ Cupfuls of Molasses
# - 1 Teaspoon of Nutmeg
# - ½ Pound of Citron
# - 4 Good-Sized Potatoes
# - 1 Quart of Boiling Water
# - 2/3 Cupful of Sugar
# - 1½ Cupful of Salt
# - 1 Cupful of Old Yeast
#
# ### Step-by-Step Instructions
# 1. Moisten with cold coffee or strong tea. Let sit for two hours.
# 2. For the potato yeast: Peel and mash the potatoes, adding the boiling water, salt, and one half cup of compressed yeast.
# 3. Stir this into a pitcher that can hold three pints; place in a warm place to rise; keep covered.
# 4. Use twice as much as one quart of flour.
#
# ### Cuisine Type
# Traditional/Comfort Food
#
# ### Dish Type
# Main Dish
#
# ### Relevant Tags/Metadata
# - Comfort Food
# - Traditional Recipe
# - Meat Dish
# - Potato Dish
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page65.jpg
# Extracted information for images/page65.jpg:
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Mince Meat
#
# ### Ingredients:
# - 4 Cupfuls of Chopped Meat
# - 2 Cupfuls of Chopped Apples
# - 2 Cupfuls of Chopped Suet
# - 4 Cupfuls of Seeded Raisins
# - 1 Cupful of Currants
# - 5 Cupfuls of Brown Sugar
# - 1⅓ Cupfuls of Molasses
# - 6 Teaspoons of Cinnamon
# - 1 Lemon (Juice and Rind)
# - 1 Egg (for binding)
#
# ### Instructions:
# 1. Moisten with cold coffee or strong tea.
# 2. Cook slowly for one hour.
#
# ### Cuisine Type:
# Traditional/Heritage
#
# ### Dish Type:
# Preserved Meat
#
# ### Relevant Tags/Metadata:
# - Mince Meat
# - Holiday Cooking
# - Preserving
# - Traditional Recipes
#
# ---
#
# ### Recipe Title:
# Home-made Potato Yeast
#
# ### Ingredients:
# - 4 Good-Sized Potatoes
# - 1⅓ Cupfuls of Salt
# - 2 Cupfuls of Sugar
#
# ### Instructions:
# 1. Boil, peel, and mash the potatoes; add the boiling water, sugar, and salt.
# 2. If yeast cannot be obtained, use this into a pitcher or container that will hold three pints; place in a warm place and cover.
# 3. Use two-thirds of a cup in one quart of flour.
#
# ### Cuisine Type:
# Traditional/Heritage
#
# ### Dish Type:
# Yeast Preparation
#
# ### Relevant Tags/Metadata:
# - Yeast
# - Baking
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page66.jpg
# Extracted information for images/page66.jpg:
# ...
# Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# Before Washing Colored Clothes
#
# ### Ingredients
# - Salt (to soak clothes)
# - Starch (for making a smooth paste)
# - Water (for soaking and mixing)
#
# ### Step-by-Step Instructions
# 1. **Soaking Colored Clothes**:
#    - Prepare a strong solution of cold water with a cup of salt.
#    - Soak the clothes for two hours.
#
# 2. **Removing Iron Rust from White Goods**:
#    - Sprinkle lemon table salt on the rust spot.
#    - Leave the item in the sun for a few hours.
#
# 3. **Making Starch Paste**:
#    - Mix two tablespoons of starch with four tablespoons of cold water to create a smooth paste.
#    - Pour over three pints of boiling water, stirring rapidly until the mixture thickens.
#
# 4. **Using Starch**:
#    - Apply the starch mixture as needed.
#
# ### Cuisine Type
# N/A (Household cleaning)
#
# ### Dish Type
# N/A (Laundry care)
#
# ### Relevant Tags/Metadata
# - Laundry tips
# - Stain removal
# - Fabric care
# - Household cleaning methods
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page120.jpg
# Extracted information for images/page120.jpg:
# Based on the content provided, here’s a structured extraction of the recipe information:
#
# ### Recipe Title
# The Proper Way to Sweep a Room
#
# ### Ingredients
# - Dust brooms
# - Newspaper
# - Small pieces of paper
# - Water
# - Ammonia
# - Cloths for polishing
#
# ### Step-by-Step Instructions
# 1. **Dust the Furniture**: Start by dusting the furniture and items in the room.
# 2. **Move Items**: If you are sweeping a bedroom, move items from the bed to another room or to the table in an adjoining room.
# 3. **Sweep Draperies**: Dust the draperies, take down and lay them on the bed.
# 4. **Prepare for Sweeping**: Use a newspaper, tear into small pieces, and spread on the rug or carpet.
# 5. **Sweep the Floor**: If the floor is carpeted, sweep dirt to the center of the room. Move every piece of furniture before sweeping.
# 6. **Use Water**: When the dust is settled, take a pail of warm water with a tablespoon of ammonia, then clean with a cloth.
# 7. **Polish**: Wipe all glass and mirrors, and polish with a dry cloth.
# 8. **Final Cleaning**: Take a pail of clean water, with ammonia, and scrub the floor. After cleaning, place the draperies back and ensure the room is tidy.
#
# ### Cuisine Type
# N/A (This is a cleaning method, not a culinary recipe)
#
# ### Dish Type
# N/A (This is a cleaning method)
#
# ### Relevant Tags or Metadata
# - Cleaning
# - Home Care
# - Household Tips
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page121.jpg
# Extracted information for images/page121.jpg:
# It seems that the image contains various tips and instructions rather than a specific recipe. Here’s a structured extraction based on the content provided:
#
# ### Recipe Information
#
# - **Title**: Various Cooking Tips
# - **Ingredients**:
#   - Dry flour (for mixing with raisins)
#   - Raisins
#   - Beets
#   - Water (for immersing roses)
#   - Grape juice or jelly (for making)
# - **Instructions**:
#   1. **When Using Currants and Raisins**: Mix a little dry flour with currants and raisins before adding them to cakes or puddings to prevent them from falling to the bottom.
#   2. **Try Baking Beets, Instead of Boiling Them**: Baking beets is recommended as they are sweeter; the cooking time is typically four hours.
#   3. **When Making Grape Juice or Jelly**: When preparing grape juice or jelly, use a strainer through a flannel bag for better results.
#   4. **When Sewing Braid on a Dress**: Slip a piece of pasteboard under the braid for about four inches long to help with sewing.
#   5. **To Skin Beets**: When removing beets from the kettle, plunge them into a dish of cold water to easily slip off the skins.
#   6. **A Fine Way to Keep Cut Roses**: Immerse cut roses at night in a pail of cold water, blossoms down.
# - **Cuisine Type**: General Cooking Tips
# - **Dish Type**: Cooking Techniques
# - **Tags/Metadata**: Cooking Tips, Kitchen Hacks, Food Preparation
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page122.jpg
# Extracted information for images/page122.jpg:
# It seems that the image contains text related to various tips and instructions rather than a specific recipe. Here’s a structured extraction based on the content provided:
#
# ### Recipe Information
#
# - **Title**: To Keep Carnations
# - **Ingredients**:
#   - Water
#   - Carnations (not explicitly listed but implied)
#
# - **Instructions**:
#   1. Put a little salt in the water, which should be changed each morning, and cut the stems a little each day.
#
# ---
#
# - **Title**: When Pies are Ready to Bake
# - **Ingredients**:
#   - Lard (or similar fat)
#   - Pie crust
#
# - **Instructions**:
#   1. Put little dabs of lard on the top crust, then hold it over the faucet, letting cold water run over it.
#
# ---
#
# - **Title**: A Way to Make Pies Brown and Shiny
# - **Ingredients**:
#   - Cheese cloth (for application)
#
# - **Instructions**:
#   1. Before putting a pie in the oven, brush over the top with milk, using a soft brush or a clean piece of cheese cloth.
#
# ---
#
# - **Title**: When Threading a Needle
# - **Instructions**:
#   1. Place a thread under the eye. You will be surprised at the ease with which you can thread it.
#
# ---
#
# - **Title**: Make Your Own Baking Powder
# - **Ingredients**:
#   - Cream of tartar
#   - Baking soda
#   - Flour
#
# - **Instructions**:
#   1. Sift together three parts cream of tartar, one part baking soda, and one part flour.
#   2. Put it in a can, and it is ready for use.
#
# ---
#
# - **Title**: To Prevent Children from Losing Mittens
# - **Instructions**:
#   1. Sew strongly to each mitten, four or five inches of elastic string (use a colored one if you prefer).
#
# ### Metadata
# - **Cuisine Type**: General cooking tips
# - **Dish Type**: Various (not specific to one dish)
# - **Tags**: Cooking tips, baking, gardening, sewing
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page123.jpg
# Extracted information for images/page123.jpg:
# Based on the content of the image, here’s the structured information extracted:
#
# ### Recipe Title
# - Teach a Child to Hang up His Own Coat and Hat
#
# ### Ingredients
# - Ribbon
# - Tape (narrow white tape)
# - Glass pen
# - Clean cloth
# - Soap (white soap)
# - Water (cold and hot)
# - Horse radish bottle
# - Soap suds
#
# ### Step-by-Step Instructions
# 1. Sew one end of the ribbon to the coat sleeve.
# 2. Allow the child to remove mittens at any time without losing them.
# 3. To keep your own umbrella:
#    - Take a piece of narrow white tape, three or four inches long.
#    - With a glass pen, write a new clean set, one indelible ink, where you want it.
#    - Sew this to the inside of the umbrella.
# 4. To wash a white silk waist or a baby’s pons:
#    - Use cold water and white soap. Hot water will turn white silk yellow.
# 5. When ironing:
#    - Right side down on a piece of flannel is not at hand, try an old Turkish towel.
# 6. To wash small pieces of lace:
#    - Put in a horse radish bottle and pour over strong soap suds, and shake well. Let sit.
#
# ### Cuisine Type
# - Not applicable (general household tips)
#
# ### Dish Type
# - Not applicable (general household tips)
#
# ### Relevant Tags/Metadata
# - Household tips
# - Childcare
# - Sewing
# - Cleaning
# - Maintenance
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page124.jpg
# Extracted information for images/page124.jpg:
# It seems that the image contains text related to various topics, but it doesn't appear to provide a specific recipe with structured components like a title, ingredients, or instructions. Instead, it includes instructions on sour milk, cottage cheese, and other household tips.
#
# If you have a specific recipe in mind or another image, please share, and I can help extract the relevant information!
#
# Processing image images/page125.jpg
# Extracted information for images/page125.jpg:
# It seems that the image contains text related to various tips and instructions rather than a specific recipe. Here’s a structured extraction based on the content provided:
#
# ### Recipe Information
#
# - **Title**: Tips for Household Management
# - **Ingredients**:
#   - Ironing wax (for ironing)
#   - Newspaper (for ironing)
#   - String (for packaging)
#   - Paper (for packaging)
#   - Fish or small pieces of bread (for fish pudding)
#   - Plaster of Paris (for mending broken china)
#   - Cream (for mending broken china)
#   - Jewelry cleaning solution (for cleaning jewelry)
#
# - **Instructions**:
#   1. Save coupons on your grocery bills.
#   2. Use a silver thimble for your mending bag.
#   3. Save string from packages for future use.
#   4. Do not throw away small pieces of bread; save them for pudding or fish pudding.
#   5. If broken into small pieces, use a jar to save for bread or other snacks.
#   6. To mend broken china, mix equal parts of arable, plaster of Paris, and cream.
#   7. For cleaning jewelry, use a solution that is good for cleaning hair brushes and combs.
#
# - **Cuisine Type**: N/A
# - **Dish Type**: N/A
# - **Tags/Metadata**: Household tips, mending, cooking, cleaning, frugality
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page126.jpg
# Extracted information for images/page126.jpg:
# It seems that I can't analyze the content of the image directly. However, if you can provide the text or details from the recipe page, I can help you extract and structure the recipe information accordingly. Please share the relevant content!
#
# Processing image images/page127.jpg
# Extracted information for images/page127.jpg:
# It seems that the image you provided contains text related to a "Space Saver" and tips for organizing items rather than a recipe. Therefore, there are no recipe components such as a title, ingredients, or instructions to extract.
#
# If you have a specific recipe or another image you'd like me to analyze, please share that!
#
# Processing image images/page128.jpg
# Extracted information for images/page128.jpg:
# It seems that the image contains text related to cooking tips and measurements rather than a specific recipe. Here’s a structured extraction based on the content provided:
#
# ### Recipe Information
#
# **Title:** Cooking Tips and Measurements
#
# **Ingredients:**
# - Water
# - Liquid (4 tablespoons = 1 tablespoon of liquid)
# - Flour (4 cups = 1 pound)
#
# **Instructions:**
# 1. When your bread cooks too quickly, use a clean piece of brown paper over it to prevent burning.
# 2. To remove the odor of onions, fill cold water kettles and saucepans with water and a tablespoon of bread. Let stand on the stove until it boils, then rinse well.
# 3. For a room with a gas leak, ensure proper ventilation as water will absorb gases.
#
# **Cuisine Type:** General Cooking Tips
#
# **Dish Type:** Cooking Techniques
#
# **Tags/Metadata:**
# - Cooking Tips
# - Measurements
# - Kitchen Hacks
# - Odor Removal
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page129.jpg
# Extracted information for images/page129.jpg:
# Based on the content of the image, here is the structured recipe information extracted:
#
# ### Recipe Title
# When to Salt Vegetables
#
# ### Ingredients
# - 1 Pint of granulated sugar (equals 1 pound)
# - 1 Coffee-cupful of cold butter (pressed down equals a cup)
# - Squash
# - Turnips
# - Onions
# - Cranberry sauce
# - Spinach
# - Mutton
# - Currant jelly
# - Vegetables (various kinds)
#
# ### Step-by-Step Instructions
# 1. **Salting Vegetables**:
#    - Every kind of food and all kinds of vegetables require a little salt when cooking.
#    - Do not wait until the vegetables are done; salt the water they are boiled in at their beginning to boil.
#
# 2. **What to Serve With Meats**:
#    - **Roast Beef and Turkey**: Serve with squash, turnips, onions, and cranberry sauce.
#    - **Roast Pork**: Serve with spinach, onions, and apple sauce.
#    - **Roast Lamb**: Serve with mutton and currant jelly.
#
# ### Cuisine Type
# Traditional/General
#
# ### Dish Type
# Vegetable Preparation/Side Dishes
#
# ### Relevant Tags/Metadata
# - Salting Techniques
# - Vegetable Cooking
# - Side Dishes
# - Meat Pairings
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page130.jpg
# Extracted information for images/page130.jpg:
# Based on the content of the image, here is the structured recipe information extracted:
#
# ### Recipe Title
# The Length of Time to Cook Meats
#
# ### Ingredients
# - Lamb
# - Veal
# - Ordinary size ham
# - Water
# - Salt
# - Vinegar
# - Sugar
# - Cloves
#
# ### Step-by-Step Instructions
# 1. **Lamb:**
#    - Wash clean, sprinkle over it a little flour and salt, and put into a pan with cold water.
#    - While it is cooking, take a spoon and pour over it the water from the pan for three or four times.
#
# 2. **Veal:**
#    - Roast veal treating it the same way as lamb.
#    - After removing it from the pan, make a smooth paste by wetting two or three tablespoonfuls of flour with cold water, and stir into the water left in the pan.
#    - Pour in more water if the size of your family requires it.
#
# 3. **Ham:**
#    - Boil a ham of ordinary size for three hours.
#    - Let cool in the water in which it is boiled.
#    - It is very nice to remove the skin while warm, stick cloves in the outside, sprinkle over it a little vinegar and sugar, and bake for one hour.
#
# ### Cuisine Type
# General Cooking
#
# ### Dish Type
# Meat Dishes
#
# ### Relevant Tags
# - Cooking Techniques
# - Meat Preparation
# - Roasting
# - Boiling
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page131.jpg
# Extracted information for images/page131.jpg:
# Based on the content of the image, here is the structured recipe information extracted:
#
# ### Recipe Title
# Corned Beef
#
# ### Ingredients
# - Corned beef (specific quantity not provided)
#
# ### Instructions
# 1. Should boil for four hours.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Main dish
#
# ### Relevant Tags/Metadata
# - Cooking time: 4 hours
# - Method: Boiling
#
# ---
#
# ### Additional Notes
# - Other cooking times for various meats and vegetables are mentioned but not detailed as recipes.
#
# Processing image images/page132.jpg
# Extracted information for images/page132.jpg:
# Based on the content of the image, here is the extracted recipe information:
#
# ### Recipe Title
# Carrots
#
# ### Ingredients
# - Carrots
#
# ### Instructions
# 1. Wash, scrape, and boil the carrots for one hour.
# 2. For peeling tomatoes, put them into very hot water to make the skin come off easily.
#
# ### Cuisine Type
# Not specified
#
# ### Dish Type
# Vegetable preparation
#
# ### Tags/Metadata
# - Cooking method: Boiling
# - Preparation time: 1 hour
# - Related ingredient: Tomatoes (for peeling)
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Processing image images/page133.jpg
# Extracted information for images/page133.jpg:
# I'm unable to analyze the content of the image as it appears to be blank. If you can provide the text or details from the recipe, I can help you structure that information.
#
# Processing image images/page134.jpg
# Extracted information for images/page134.jpg:
# I'm unable to analyze the content of the image as it appears to be blank. If you can provide the text or details from the recipe, I can help you structure that information.
#
# Processing image images/page135.jpg
# Extracted information for images/page135.jpg:
# I'm unable to analyze the content of the image as it appears to be blank. If you can provide the text or details from the recipe, I can help you structure that information.
#
# Processing image images/page136.jpg
# Extracted information for images/page136.jpg:
# I'm unable to analyze the content of the image directly. If you can provide the text or details from the recipe, I can help you structure that information into the desired format.

# %%
# Filter out non-recipe content based on key recipe-related terms
filtered_recipes = []

for recipe in extracted_recipes:
  # Check if the extracted content contains any key recipe-related terms
  if any(keyword in recipe["recipe_info"].lower() for keyword in ["ingredients",
                                                                  "instructions",
                                                                  "recipe title"]):
     # If it does, add it to the filtered list
    filtered_recipes.append(recipe)

  # Print a message for non-recipe content
  else:
    print(f"Skipping recipe: {recipe['image_path']}")
# Out:
# Skipping recipe: images/page1.jpg
# Skipping recipe: images/page2.jpg
# Skipping recipe: images/page3.jpg
# Skipping recipe: images/page4.jpg
# Skipping recipe: images/page5.jpg
# Skipping recipe: images/page6.jpg
# Skipping recipe: images/page8.jpg
# Skipping recipe: images/page10.jpg
# Skipping recipe: images/page11.jpg
# Skipping recipe: images/page12.jpg
# Skipping recipe: images/page20.jpg
# Skipping recipe: images/page21.jpg
# Skipping recipe: images/page22.jpg
# Skipping recipe: images/page106.jpg
# Skipping recipe: images/page107.jpg
# Skipping recipe: images/page108.jpg
# Skipping recipe: images/page112.jpg
# Skipping recipe: images/page126.jpg
# Skipping recipe: images/page133.jpg
# Skipping recipe: images/page134.jpg
# Skipping recipe: images/page135.jpg
# Skipping recipe: images/page136.jpg

# %%
# import json library
import json

# %%
# Define the output file path
output_file = "recipe_info.json"

# Write the filtered list to a json file
with open(output_file, "w") as json_file:
  json.dump(filtered_recipes, json_file, indent = 4)

# %% [markdown]
# # Embeddings

# %%
# import libraries
import numpy as np

# %%
# Load the filtered recipes
with open("recipe_info.json", "r") as json_file:
  filtered_recipes = json.load(json_file)

# %% [markdown]
# another options would be to organize per recipe, but it should be done in the preprocessing

# %%
# Generate embeddings for each recipe
recipe_texts = [recipe["recipe_info"] for recipe in filtered_recipes] # Extract the text content of each recipe

# Call the API to generate embeddings for the recipe texts
embedding_response = client.embeddings.create(
    input = recipe_texts, # Provide the list of recipe texts as input
    model = "text-embedding-3-large" # Specify the embedding model to use
)

# %%
# Extract the embeddings
embeddings = [data.embedding for data in embedding_response.data]
embeddings
# Out:
# [[-0.018192430958151817,
#   -0.03411807492375374,
#   -0.0201831366866827,
#   -0.015010208822786808,
#   0.026213375851511955,
#   -0.035687390714883804,
#   -0.016187194734811783,
#   0.0008405099506489933,
#   -0.015751274302601814,
#   0.023336296901106834,
#   0.030049478635191917,
#   -0.03905851021409035,
#   -0.007512369658797979,
#   0.013651588931679726,
#   0.03034009411931038,
#   -0.03728576749563217,
#   -0.013956733047962189,
#   0.031240995973348618,
#   -0.010883491486310959,
#   -0.054228559136390686,
#   0.016419686377048492,
#   -0.0006638711784034967,
#   0.04240057244896889,
#   0.008747478947043419,
#   -0.015068331733345985,
#   -0.0026500357780605555,
#   -0.037605442106723785,
#   0.006851223297417164,
#   0.017131689935922623,
#   0.01920958049595356,
#   0.010542020201683044,
#   0.023103807121515274,
#   0.017451366409659386,
#   -0.024309854954481125,
#   -0.02778269164264202,
#   -0.028392979875206947,
#   0.008355149999260902,
#   0.04292367771267891,
#   0.03504803776741028,
#   0.026271497830748558,
#   0.026431335136294365,
#   -0.010171486996114254,
#   0.006277260836213827,
#   0.021287469193339348,
#   -0.054664477705955505,
#   -0.028320325538516045,
#   -0.002241359790787101,
#   -0.014436246827244759,
#   -0.011043328791856766,
#   -0.04428956285119057,
#   0.01729152910411358,
#   -0.015010208822786808,
#   -0.0031513446010649204,
#   0.002653668401762843,
#   0.014189224690198898,
#   0.022595232352614403,
#   0.027840813621878624,
#   -0.02224649488925934,
#   0.00563427759334445,
#   0.06126141548156738,
#   0.012067742645740509,
#   -0.01942753978073597,
#   -0.012053212150931358,
#   0.02159261330962181,
#   0.01612907275557518,
#   -0.01874459721148014,
#   0.014784983359277248,
#   0.051089927554130554,
#   0.03722764179110527,
#   0.03844822198152542,
#   0.002219563815742731,
#   -0.03987222909927368,
#   -0.001677387161180377,
#   0.0017872756579890847,
#   0.023350829258561134,
#   0.0027226891834288836,
#   -0.025966353714466095,
#   -0.059401486068964005,
#   -0.0005358193884603679,
#   -0.0017273364355787635,
#   -0.005441745743155479,
#   0.008100862614810467,
#   -0.006328118033707142,
#   0.008086332120001316,
#   0.021636206656694412,
#   -0.03057258389890194,
#   -0.028538286685943604,
#   -0.049200937151908875,
#   0.009038092568516731,
#   0.049433428794145584,
#   -0.01569315232336521,
#   -0.0049949269741773605,
#   -0.0124673368409276,
#   -0.019064273685216904,
#   0.0006048402283340693,
#   0.028756247833371162,
#   0.038099486380815506,
#   -0.013825957663357258,
#   -0.034466810524463654,
#   0.021854165941476822,
#   -0.012169457972049713,
#   -0.009897482581436634,
#   0.016484636813402176,
#   -0.016578450798988342,
#   -0.008912425488233566,
#   -0.0033455099910497665,
#   0.012202652171254158,
#   -0.010024803690612316,
#   0.0007145017734728754,
#   -0.001891377498395741,
#   -0.0001959016517503187,
#   -0.015037205070257187,
#   0.005042556673288345,
#   0.005092814564704895,
#   -0.009066550061106682,
#   0.0006035153055563569,
#   -0.025584692135453224,
#   0.005608797073364258,
#   -0.0075186025351285934,
#   0.01182739157229662,
#   0.015613497234880924,
#   -0.007947470992803574,
#   0.007371178828179836,
#   -0.03165586292743683,
#   0.00798097625374794,
#   -0.021523842588067055,
#   -0.0007446566014550626,
#   -0.017972273752093315,
#   0.031200191006064415,
#   -0.02692490629851818,
#   0.01604236662387848,
#   0.03173627704381943,
#   0.002372179413214326,
#   -0.011559348553419113,
#   -0.00845005176961422,
#   0.01580112800002098,
#   -0.03610537573695183,
#   0.01476916205137968,
#   0.018293926492333412,
#   0.017114536836743355,
#   0.0018042635638266802,
#   -0.029833171516656876,
#   -0.01720835268497467,
#   0.030878538265824318,
#   -0.017650622874498367,
#   -0.022931067273020744,
#   -0.008952631615102291,
#   0.0034242477267980576,
#   0.035301245748996735,
#   0.0034242477267980576,
#   0.028787804767489433,
#   0.030235236510634422,
#   0.008818610571324825,
#   0.020773323252797127,
#   -0.043610576540231705,
#   0.033076491206884384,
#   -0.009046446532011032,
#   -0.01720835268497467,
#   0.0056456527672708035,
#   0.055431265383958817,
#   0.019567130133509636,
#   -0.006319110747426748,
#   -0.0241104569286108,
#   0.0201434213668108,
#   -0.04551367834210396,
#   -0.003166256472468376,
#   0.008999539539217949,
#   -0.01514442265033722,
#   0.03554248437285423,
#   0.01608257181942463,
#   -0.0006441405275836587,
#   0.009167065843939781,
#   -0.01172687578946352,
#   0.020893942564725876,
#   0.055752918124198914,
#   -0.008925827220082283,
#   -0.004948741290718317,
#   -0.011405223980545998,
#   -0.001258963835425675,
#   0.00281445006839931,
#   0.007840254344046116,
#   0.0177578404545784,
#   0.05462713539600372,
#   -0.020746517926454544,
#   ...]]

# %%
# Convert the embeddings to numpy array
embedding_matrix = np.array(embeddings)
embedding_matrix
# Out:
# array([[-0.01819243, -0.03411807, -0.02018314, ..., -0.00173733,
#         -0.02522529,  0.00684396],
#        [-0.01819243, -0.03411807, -0.02018314, ..., -0.00173733,
#         -0.02522529,  0.00684396],
#        [-0.00356826, -0.03058816, -0.01480166, ..., -0.00345601,
#         -0.01368646,  0.02147833],
#        ...,
#        [-0.01836957, -0.03246572, -0.01109092, ...,  0.00375077,
#         -0.00479223,  0.00559542],
#        [-0.00718078, -0.02741507, -0.01103076, ...,  0.00263969,
#          0.00469953, -0.00361736],
#        [-0.0362394 , -0.03605177, -0.01267173, ..., -0.00439255,
#         -0.00796757,  0.00993099]])

# %%
# Verify the embedding matrix
print(f"Generated embeddings for {len(filtered_recipes)} recipes.")
print(f"Each embedding is of size {len(embeddings[0])}")
# Out:
# Generated embeddings for 114 recipes.
# Each embedding is of size 3072

# %% [markdown]
# Each time we retrieve information, we may get different results

# %% [markdown]
# # Retrieval System

# %%
# Install the faiss-cpu library
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.9.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 19.3 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.9.0.post1

# %%
# Import the faiss library
import faiss

# %%
# Print the embedding matrix shape
print(f"Embedding matrix shape: {embedding_matrix.shape}")
# Out:
# Embedding matrix shape: (114, 3072)

# %%
# Initialize the FAISS index for similarity search
index = faiss.IndexFlatL2(embedding_matrix.shape[1]) # Create a FAISS index with L2 distance metric
index.add(embedding_matrix) # Add the embeddings to the index

# %%
# Save the FAISS index to a file
faiss.write_index(index, "filtered_recipe_index.index")

# %%
# Save the metadata for each recipe
metadata = [{'recipe_info': recipe['recipe_info'], # Include recipe information
             'image_path': recipe['image_path']} for recipe in filtered_recipes] # Include image path

# Write metadata to a JSON file with indentation
with open("recipe_metadata.json", "w") as json_file:
  json.dump(metadata, json_file, indent = 4)

# %%
# Generate the embeddings for the query
query = "How to make bread?"
k = 5 # Number of top results to retrieve
query_embedding = client.embeddings.create(
    input = [query],
    model = "text-embedding-3-large"
).data[0].embedding
print(f"The query embedding is {query_embedding}\n")
query_vector = np.array(query_embedding).reshape(1, -1)  # Convert embedding to a 2D numpy array for FAISS
print(f"The query vector is {query_vector}\n")

# Search the FAISS index for the nearest neighbors
distances, indices = index.search(query_vector, min(k, len(metadata))) # Perform the search
print(f"The distances are {distances}\n")
print(f"The indices are {indices}\n")

# Store the indices and distances
stored_indices = indices[0].tolist()
stored_distances = distances[0].tolist()
print(f"The stored indices are {stored_indices}\n")
print(f"The stored distances are {stored_distances}\n")

# Print the metadata content for the top results
print("The metadata content is")
for i, dist in zip(stored_indices, stored_distances):
  if 0 <=i < len(metadata):
    print(f"Distance: {dist}, Metadata: {metadata[i]['recipe_info']}")

# Return the results
results = [(metadata[i]['recipe_info'], dist) for i, dist in zip(stored_indices, stored_distances) if 0 <= i < len(metadata)]
results # Output the results as a list of tuples containing recipe info and distance
# Out:
# The query embedding is [-0.019708624109625816, -0.028040051460266113, -0.022090725600719452, 0.016627300530672073, -0.04790274053812027, -0.048874542117118835, 0.03797139599919319, 0.01790723390877247, 0.0015688088024035096, 0.004139048047363758, -0.004817531909793615, -0.013901513069868088, -0.012917859479784966, -0.0015480691799893975, 0.03806620463728905, -0.02385655976831913, 0.016994688659906387, -0.016651002690196037, -0.007258888799697161, 0.002297660568729043, -0.03185615316033363, 0.02015897072851658, 0.014991827309131622, -0.007780343759804964, 0.006287086755037308, 0.017836127430200577, 0.003407233627513051, -0.011205354705452919, -0.03963056951761246, 0.042308952659368515, -0.0036798121873289347, 0.023690642789006233, -0.03465304523706436, -0.021154476329684258, -0.01591622456908226, 0.011329792439937592, -0.01473109982907772, 0.005253065377473831, 0.008515121415257454, 0.019412342458963394, -0.012408255599439144, 0.007792194839566946, 0.00038775798748247325, -0.008254393935203552, -0.012467511929571629, 0.016544342041015625, 0.06229015439748764, 0.019684921950101852, -0.015548836439847946, -0.011513486504554749, 0.046053946018218994, 0.008461790159344673, 0.03894319757819176, 0.00098513497505337, -0.02713935635983944, 0.06679362803697586, 0.012230487540364265, -0.04579322040
metadata: Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title:
# Nut Bread and Oatmeal Bread
#
# ### Ingredients:
# #### Nut Bread:
# - 2½ Cups of Flour
# - 3 Teaspoons of Baking Powder
# - ¾ Cup of Milk
# - ½ Cup of Sugar
# - 1 Cup of Nuts, chopped
#
# #### Oatmeal Bread:
# - 2¾ Cups of Rolled Oats
# - 1½ Cups of Molasses
# - 1 Yeast Cake
# - Water
#
# ### Instructions:
# #### Nut Bread:
# 1. Mix flour, baking powder, and sugar together.
# 2. Add chopped nuts.
# 3. Stir in milk until well combined.
# 4. Pour into a greased loaf pan.
# 5. Bake for one hour.
#
# #### Oatmeal Bread:
# 1. Boil oats and water until cool.
# 2. Add molasses and yeast cake; stir until mixed.
# 3. Let the mixture sit until it rises.
# 4. Shape into a loaf and let rise again.
# 5. Bake for one hour.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Bread
#
# ### Tags/Metadata:
# - Baking
# - Quick Bread
# - Homemade Bread
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
# Distance: 1.1365714073181152, Metadata: Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Breads
#
# ### Ingredients
# #### Bannocks
# - 1 Cupful of Thick Sour Milk
# - ½ Cupful of Sugar
# - 2 Cupfuls of Flour
# - ½ Cupful of Indian Meal
# - 1 Teaspoonful of Soda
# - A pinch of Salt
#
# #### Boston Brown Bread
# - 1 Cupful of Rye Meal
# - 1 Cupful of Graham Meal
# - 1 Cupful of Molasses
# - 1 Cupful of Flour
# - 1 Cupful of Sour Milk
# - ½ Teaspoonful of Salt
# - 1 Teaspoonful of Soda
# - 1 Heaping Teaspoonful of Sweet Milk
#
# ### Step-by-Step Instructions
# 1. For Bannocks: Make the mixture stiff enough to drop from a spoon. Drop mixture, size of a walnut, into boiling fat. Serve warm, with maple syrup.
# 2. For Boston Brown Bread: Stir the meals and salt together. Beat the soda into the molasses until it foams; add sour milk, mix well, and pour into a tin pan which has been well greased. If you have no brown-bread steamer, use a regular oven.
#
# ### Cuisine Type
# Traditional American
#
# ### Dish Type
# Breads
#
# ### Relevant Tags/Metadata
# - Baking
# - Quick Bread
# - Traditional Recipes
# - Comfort Food
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
# Distance: 1.1599339246749878, Metadata: Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Title
# - Various Bread Recipes
#
# ### List of Ingredients
# - Not specified in the image.
#
# ### Step-by-Step Instructions
# - Not specified in the image.
#
# ### Cuisine Type
# - Breads
#
# ### Dish Type
# - Various types of bread
#
# ### Relevant Tags or Metadata
# - Bannocks
# - Boston Brown Bread
# - Brown Bread (Baked)
# - Coffee Cakes
# - Corn Meal Gems
# - Cream of Tartar Biscuits
# - Crullers
# - Delicious Drop Biscuits
# - Doughnuts
# - Fried Bread
# - Graham Toast
# - Soft Gingerbread
# - Huckleberry Cake
# - Quick Graham Bread
# - Graham Flour (Raised Over Night)
# - Graham Muffins
# - Sweet Milk Griddle Cakes
# - Jenny Lind Tea Cake
# - Real Johnny Cakes
# - New England Buns
# - Nut Bread
# - Oatmeal Bread
# - Parker House Rolls
# - Popovers
# - Rye Muffins
# - Breakfast Sally Lunn
#
# This structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.
# Distance: 1.1602239608764648, Metadata: Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Graham Bread (raised over night)
#
# ### Ingredients
# - 3 Cupfuls of Graham Flour
# - 1 Tablespoonful of Lard
# - 3 Cupfuls of Warm Water
# - ½ Teaspoonful of Salt
# - 1 Tablespoonful of Sugar
# - 1 Package of Yeast
# - 1 Cupful of Milk (for Graham Muffins)
# - ½ Pint of White Flour (for Graham Muffins)
# - ½ Cupful of Molasses (for Graham Muffins)
# - ½ Teaspoonful of Salt (for Graham Muffins)
# - 2 Cupfuls of Sour Milk (for Sour Milk Griddle Cakes)
# - ½ Teaspoonful of Salt (for Sour Milk Griddle Cakes)
# - Soda (for Sour Milk Griddle Cakes)
#
# ### Step-by-Step Instructions
# 1. **Graham Bread:**
#    - Mix flour and lard together and rub in lard.
#    - Add yeast cake which has been dissolved in one-half cup of cold water.
#    - Mix with warm water at night.
#    - Set in a warm place to rise.
#    - In the morning, stir and let rise twice its bulk.
#    - Knead and put in baking pans. Let rise for about forty-five minutes.
#
# 2. **Graham Muffins:**
#    - Put the salt and soda into the molasses.
#    - Stir until blended and mix with milk or water.
#    - Drop into muffin tins and bake for twenty minutes.
#
# 3. **Sour Milk Griddle Cakes:**
#    - Stir the soda and salt into the milk and add enough flour to make thin batter.
#    - Cook on a well-greased griddle.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread, Muffins, Griddle Cakes
#
# ### Relevant Tags/Metadata
# - Baking
# - Yeast Bread
# - Breakfast
# - Traditional Recipes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
# Distance: 1.2071425914764404, Metadata: Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Brown Bread (Baked)
#
# ### Ingredients
# - 1 Cupful of Indian Meal
# - 1 Cupful of Molasses
# - 1 Cupful of Rye Meal
# - ½ Cupful of Flour
# - 1 Cupful of Water
# - 1 Teaspoon of Soda
#
# ### Instructions
# 1. Put the meal and flour together.
# 2. Stir soda into molasses until it foams.
# 3. Add the mixture to the meal and water.
# 4. Mix all together.
# 5. Pour into a greased tin and cover on for two and a half hours.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Bread
#
# ### Relevant Tags
# - Baking
# - Bread
# - Traditional Recipes
#
# ---
#
# ### Recipe Title
# Corn Meal Gems
#
# ### Ingredients
# - 2 Cupfuls of Flour
# - 1 Cupful of Corn Meal
# - 2 Eggs (beaten)
# - 1 Cupful of Milk
# - ½ Cupful of Sugar
# - ½ Teaspoon of Soda
# - ½ Teaspoon of Salt
# - ½ Teaspoon of Cream of Tartar
#
# ### Instructions
# 1. Stir the flour and meal together.
# 2. Add the corn meal, soda, salt, and sugar.
# 3. Beat the egg and add cream of tartar, milk.
# 4. Mix all ingredients together.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Muffins
#
# ### Relevant Tags
# - Baking
# - Muffins
# - Traditional Recipes
#
# This structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
# [('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title:\nNut Bread and Oatmeal Bread\n\n### Ingredients:\n#### Nut Bread:\n- 2½ Cups of Flour\n- 3 Teaspoons of Baking Powder\n- ¾ Cup of Milk\n- ½ Cup of Sugar\n- 1 Cup of Nuts, chopped\n\n#### Oatmeal Bread:\n- 2¾ Cups of Rolled Oats\n- 1½ Cups of Molasses\n- 1 Yeast Cake\n- Water\n\n### Instructions:\n#### Nut Bread:\n1. Mix flour, baking powder, and sugar together.\n2. Add chopped nuts.\n3. Stir in milk until well combined.\n4. Pour into a greased loaf pan.\n5. Bake for one hour.\n\n#### Oatmeal Bread:\n1. Boil oats and water until cool.\n2. Add molasses and yeast cake; stir until mixed.\n3. Let the mixture sit until it rises.\n4. Shape into a loaf and let rise again.\n5. Bake for one hour.\n\n### Cuisine Type:\nAmerican\n\n### Dish Type:\nBread\n\n### Tags/Metadata:\n- Baking\n- Quick Bread\n- Homemade Bread\n- Traditional Recipes\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.128458023071289),
#  ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nBreads\n\n### Ingredients\n#### Bannocks\n- 1 Cupful of Thick Sour Milk\n- ½ Cupful of Sugar\n- 2 Cupfuls of Flour\n- ½ Cupful of Indian Meal\n- 1 Teaspoonful of Soda\n- A pinch of Salt\n\n#### Boston Brown Bread\n- 1 Cupful of Rye Meal\n- 1 Cupful of Graham Meal\n- 1 Cupful of Molasses\n- 1 Cupful of Flour\n- 1 Cupful of Sour Milk\n- ½ Teaspoonful of Salt\n- 1 Teaspoonful of Soda\n- 1 Heaping Teaspoonful of Sweet Milk\n\n### Step-by-Step Instructions\n1. For Bannocks: Make the mixture stiff enough to drop from a spoon. Drop mixture, size of a walnut, into boiling fat. Serve warm, with maple syrup.\n2. For Boston Brown Bread: Stir the meals and salt together. Beat the soda into the molasses until it foams; add sour milk, mix well, and pour into a tin pan which has been well greased. If you have no brown-bread steamer, use a regular oven.\n\n### Cuisine Type\nTraditional American\n\n### Dish Type\nBreads\n\n### Relevant Tags/Metadata\n- Baking\n- Quick Bread\n- Traditional Recipes\n- Comfort Food\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.1365714073181152),
#  ('Based on the content of the image, here is the structured information extracted:\n\n### Recipe Title\n- Various Bread Recipes\n\n### List of Ingredients\n- Not specified in the image.\n\n### Step-by-Step Instructions\n- Not specified in the image.\n\n### Cuisine Type\n- Breads\n\n### Dish Type\n- Various types of bread\n\n### Relevant Tags or Metadata\n- Bannocks\n- Boston Brown Bread\n- Brown Bread (Baked)\n- Coffee Cakes\n- Corn Meal Gems\n- Cream of Tartar Biscuits\n- Crullers\n- Delicious Drop Biscuits\n- Doughnuts\n- Fried Bread\n- Graham Toast\n- Soft Gingerbread\n- Huckleberry Cake\n- Quick Graham Bread\n- Graham Flour (Raised Over Night)\n- Graham Muffins\n- Sweet Milk Griddle Cakes\n- Jenny Lind Tea Cake\n- Real Johnny Cakes\n- New England Buns\n- Nut Bread\n- Oatmeal Bread\n- Parker House Rolls\n- Popovers\n- Rye Muffins\n- Breakfast Sally Lunn\n\nThis structured format can be used for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.1599339246749878),
#  ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nGraham Bread (raised over night)\n\n### Ingredients\n- 3 Cupfuls of Graham Flour\n- 1 Tablespoonful of Lard\n- 3 Cupfuls of Warm Water\n- ½ Teaspoonful of Salt\n- 1 Tablespoonful of Sugar\n- 1 Package of Yeast\n- 1 Cupful of Milk (for Graham Muffins)\n- ½ Pint of White Flour (for Graham Muffins)\n- ½ Cupful of Molasses (for Graham Muffins)\n- ½ Teaspoonful of Salt (for Graham Muffins)\n- 2 Cupfuls of Sour Milk (for Sour Milk Griddle Cakes)\n- ½ Teaspoonful of Salt (for Sour Milk Griddle Cakes)\n- Soda (for Sour Milk Griddle Cakes)\n\n### Step-by-Step Instructions\n1. **Graham Bread:**\n   - Mix flour and lard together and rub in lard.\n   - Add yeast cake which has been dissolved in one-half cup of cold water.\n   - Mix with warm water at night.\n   - Set in a warm place to rise.\n   - In the morning, stir and let rise twice its bulk.\n   - Knead and put in baking pans. Let rise for about forty-five minutes.\n\n2. **Graham Muffins:**\n   - Put the salt and soda into the molasses.\n   - Stir until blended and mix with milk or water.\n   - Drop into muffin tins and bake for twenty minutes.\n\n3. **Sour Milk Griddle Cakes:**\n   - Stir the soda and salt into the milk and add enough flour to make thin batter.\n   - Cook on a well-greased griddle.\n\n### Cuisine Type\nAmerican\n\n### Dish Type\nBread, Muffins, Griddle Cakes\n\n### Relevant Tags/Metadata\n- Baking\n- Yeast Bread\n- Breakfast\n- Traditional Recipes\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.1602239608764648),
#  ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nBrown Bread (Baked)\n\n### Ingredients\n- 1 Cupful of Indian Meal\n- 1 Cupful of Molasses\n- 1 Cupful of Rye Meal\n- ½ Cupful of Flour\n- 1 Cupful of Water\n- 1 Teaspoon of Soda\n\n### Instructions\n1. Put the meal and flour together.\n2. Stir soda into molasses until it foams.\n3. Add the mixture to the meal and water.\n4. Mix all together.\n5. Pour into a greased tin and cover on for two and a half hours.\n\n### Cuisine Type\nAmerican\n\n### Dish Type\nBread\n\n### Relevant Tags\n- Baking\n- Bread\n- Traditional Recipes\n\n---\n\n### Recipe Title\nCorn Meal Gems\n\n### Ingredients\n- 2 Cupfuls of Flour\n- 1 Cupful of Corn Meal\n- 2 Eggs (beaten)\n- 1 Cupful of Milk\n- ½ Cupful of Sugar\n- ½ Teaspoon of Soda\n- ½ Teaspoon of Salt\n- ½ Teaspoon of Cream of Tartar\n\n### Instructions\n1. Stir the flour and meal together.\n2. Add the corn meal, soda, salt, and sugar.\n3. Beat the egg and add cream of tartar, milk.\n4. Mix all ingredients together.\n\n### Cuisine Type\nAmerican\n\n### Dish Type\nMuffins\n\n### Relevant Tags\n- Baking\n- Muffins\n- Traditional Recipes\n\nThis structured format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.',
#   1.2071425914764404)]

# %%
# Define a function to query the embeddings
def query_embeddings(query, index, metadata, k = 5):
  # Generate the embeddings for the query
  query_embedding = client.embeddings.create(
      input = [query],
      model = "text-embedding-3-large"
  ).data[0].embedding
  print(f"The query embedding is {query_embedding}\n")
  query_vector = np.array(query_embedding).reshape(1, -1)
  print(f"The query vector is {query_vector}\n")

  # Search faiss index
  distances, indices = index.search(query_vector, min(k, len(metadata)))
  # print(f"The distances are {distances}\n")
  # print(f"The indices are {indices}\n")

  # Store the indices and distances
  stored_indices = indices[0].tolist()
  stored_distances = distances[0].tolist()
  print(f"The stored indices are {stored_indices}\n")
  print(f"The stored distances are {stored_distances}\n")

  # # Print the metadata content
  # print("The metadata content is")
  # for i, dist in zip(stored_indices, stored_distances):
  #   if 0 <=i < len(metadata):
  #     print(f"Distance: {dist}, Metadata: {metadata[i]['recipe_info']}")

  # Return the results
  results = [(
      metadata[i]['recipe_info'], dist) for i, dist in zip(
          stored_indices, stored_distances) if 0 <= i < len(metadata)]
  return results

# %%
# Test the retrieval system
query = "chocolate query"
results = query_embeddings(query, index, metadata)
print(f"The results are {results}")
# Out:
# The query embedding is [-0.014632204547524452, -0.005892922170460224, -0.016869252547621727, -0.006876526866108179, -0.03285064920783043, 0.00999272521585226, 0.023484645411372185, 0.051948241889476776, -0.015319856815040112, 0.0464470200240612, 0.005814582109451294, -0.018105285242199898, -0.04975471645593643, 0.007598997093737125, -0.025800032541155815, 0.014623500406742096, -0.013761757872998714, -0.015163176693022251, -0.020403264090418816, -0.030204491689801216, 0.02104739472270012, -0.01762654073536396, -0.005466403439640999, 0.02754092402756214, 0.023345373570919037, 0.049232449382543564, -0.01134191732853651, -
# The query vector is [[-1.46322045e-02 -5.89292217e-03 -1.68692525e-02 ...  1.37443487e-02
#   -1.19947521e-02  8.29644268e-05]]
#
# The stored indices are [8, 83, 84, 29, 78]
#
# The stored distances are [1.1822062730789185, 1.2990531921386719, 1.3263275623321533, 1.3324439525604248, 1.3716334104537964]
#
# The results are [('Based on the content of the image, here is the structured information extracted:\n\n### Recipe Information\n\n- **Title**: Chocolate Sauce\n- **Cuisine Type**: Not specified\n- **Dish Type**: Sauce\n- **Ingredients**: Not listed in the image\n- **Instructions**: Not listed in the image\n- **Relevant Tags/Metadata**: Sauces, Desserts\n\n### Additional Recipes Listed\n1. **COLD SAUCE**\n2. **CRANBERRY SAUCE**\n3. **CREAM MUSTARD**\n4. **EGG SAUCE FOR CHOCOLATE PUDDING**\n5. **PUDDING SAUCE**\n6. **SAUCE FOR GRAHAM PUDDING**\n\n### Sections\n- **Soups**\n  - Bean Porridge\n  - Connecticut Clam Chowder\n  - Massachusetts Clam Chowder\n  - New England Fish Chowder\n  - Lamb Broth\n  - A Good Oyster Stew\n  - Potato Soup\n\n- **Vegetables**\n  - Green Corn Fritters\n  - Delicious Stuffed Baked Potatoes\n  - Creamed Potatoes\n  - Scalloped Potatoes\n  - Baked Tomatoes\n  - Fried Tomatoes\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.', 1.1822062730789185), ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nSauces\n\n### Ingredients\n#### Chocolate Sauce\n- 1 Tablespoon of Butter\n- 1 Cup of Sugar\n- 2 Tablespoons of Boiling Cocoa\n- 1 Cup of Water\n\n#### Cold Sauce\n- 1 Cup of Butter\n- 1.5 Cups of Sugar\n- 1 Nutmeg (for grating)\n\n#### Cranberry Sauce\n- 1 Cup of Cranberries\n\n#### Cream Mustard\n- ½ Cup of Vinegar\n- ½ Cup of Sweet Cream\n- 1 Tablespoon of Mustard\n- 1 Egg\n\n### Instructions\n#### Chocolate Sauce\n1. Put the butter into an agate dish on the stove.\n2. When melted, stir in the cocoa and sugar dry; add boiling water and stir until smooth.\n3. Add vanilla to taste.\n\n#### Cold Sauce\n1. Cream together butter and sugar.\n2. Grate a little nutmeg over the top.\n\n#### Cranberry Sauce\n1. Pick over and wash one cup of cranberries.\n2. Cover with cold water and cook until tender.\n3. Remove from the fire, rub through a colander, and sweeten to taste.\n\n#### Cream Mustard\n1. Put the vinegar on the stove and let it come to a boil.\n\n### Cuisine Type\nGeneral Sauces\n\n### Dish Type\nSauces\n\n### Tags/Metadata\n- Sauces\n- Dessert\n- Condiments\n- Cooking Techniques\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.', 1.2990531921386719), ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nEgg Sauce for Chocolate Pudding\n\n### Ingredients\n- **For Egg Sauce:**\n  - 2 Cups of Sugar\n  - 1 Cupful of Boiling Milk\n  - ½ Cupful of Butter\n  - 1 Cupful of Milk\n  - Flavoring (to taste)\n\n- **For Pudding Sauce:**\n  - 1 Cupful of Sugar\n  - 3 Heaping Teaspoons of Cornstarch\n  - 1 Pint of Water\n  - Flavoring (to taste)\n\n- **For Salad Dressing:**\n  - 1 Egg\n  - 2 Tablespoons of Sugar\n  - 1 Tablespoon of Flour\n  - ½ Cupful of Vinegar\n  - ½ Cupful of Walnut\n  - ½ Cupful of Milk\n  - 1 Teaspoonful of Mustard\n  - 1 Teaspoonful of Salt\n\n### Step-by-Step Instructions\n1. For the egg sauce, cream the sugar and butter together, then add boiling milk and stir constantly until thickened. Let it cool before use.\n2. For the pudding sauce, mix sugar and cornstarch in a pint of boiling water, then add flavoring.\n3. For the salad dressing, beat the egg and mix with sugar, flour, vinegar, walnut, milk, mustard, and salt.\n\n### Cuisine Type\nAmerican\n\n### Dish Type\nSauce/Dressing\n\n### Relevant Tags/Metadata\n- Dessert\n- Sauces\n- Pudding\n- Salad Dressing\n\nThis format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.', 1.3263275623321533), ('Here’s the structured information extracted from the recipe image:\n\n### Recipe Title\nOld-Fashioned Candies\n\n### Ingredients\n#### Chocolate Taffy\n- 1½ Cups of Molasses\n- 1½ Cups of Sugar\n- ½ Cup of Milk\n- 2 Squares of Chocolate\n- 1 Small Teaspoon of Flour\n- Butter (for greasing)\n\n#### Molasses Candy\n- 2 Cups of Molasses\n- ¼ Teaspoon of Soda\n- 2 Teaspoons of Vin ...

# %%
# Combine the results into a single string
def combined_retrived_content(results):
  combined_content = "\n\n".join([result[0] for result in results]) # Join the recipe information with double newlines
  return combined_content

# Get the combined content from results
combined_content = combined_retrived_content(results)
print(f"The combined content is {combined_content}")
# Out:
# The combined content is Based on the content of the image, here is the structured information extracted:
#
# ### Recipe Information
#
# - **Title**: Chocolate Sauce
# - **Cuisine Type**: Not specified
# - **Dish Type**: Sauce
# - **Ingredients**: Not listed in the image
# - **Instructions**: Not listed in the image
# - **Relevant Tags/Metadata**: Sauces, Desserts
#
# ### Additional Recipes Listed
# 1. **COLD SAUCE**
# 2. **CRANBERRY SAUCE**
# 3. **CREAM MUSTARD**
# 4. **EGG SAUCE FOR CHOCOLATE PUDDING**
# 5. **PUDDING SAUCE**
# 6. **SAUCE FOR GRAHAM PUDDING**
#
# ### Sections
# - **Soups**
#   - Bean Porridge
#   - Connecticut Clam Chowder
#   - Massachusetts Clam Chowder
#   - New England Fish Chowder
#   - Lamb Broth
#   - A Good Oyster Stew
#   - Potato Soup
#
# - **Vegetables**
#   - Green Corn Fritters
#   - Delicious Stuffed Baked Potatoes
#   - Creamed Potatoes
#   - Scalloped Potatoes
#   - Baked Tomatoes
#   - Fried Tomatoes
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Sauces
#
# ### Ingredients
# #### Chocolate Sauce
# - 1 Tablespoon of Butter
# - 1 Cup of Sugar
# - 2 Tablespoons of Boiling Cocoa
# - 1 Cup of Water
#
# #### Cold Sauce
# - 1 Cup of Butter
# - 1.5 Cups of Sugar
# - 1 Nutmeg (for grating)
#
# #### Cranberry Sauce
# - 1 Cup of Cranberries
#
# #### Cream Mustard
# - ½ Cup of Vinegar
# - ½ Cup of Sweet Cream
# - 1 Tablespoon of Mustard
# - 1 Egg
#
# ### Instructions
# #### Chocolate Sauce
# 1. Put the butter into an agate dish on the stove.
# 2. When melted, stir in the cocoa and sugar dry; add boiling water and stir until smooth.
# 3. Add vanilla to taste.
#
# #### Cold Sauce
# 1. Cream together butter and sugar.
# 2. Grate a little nutmeg over the top.
#
# #### Cranberry Sauce
# 1. Pick over and wash one cup of cranberries.
# 2. Cover with cold water and cook until tender.
# 3. Remove from the fire, rub through a colander, and sweeten to taste.
#
# #### Cream Mustard
# 1. Put the vinegar on the stove and let it come to a boil.
#
# ### Cuisine Type
# General Sauces
#
# ### Dish Type
# Sauces
#
# ### Tags/Metadata
# - Sauces
# - Dessert
# - Condiments
# - Cooking Techniques
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Egg Sauce for Chocolate Pudding
#
# ### Ingredients
# - **For Egg Sauce:**
#   - 2 Cups of Sugar
#   - 1 Cupful of Boiling Milk
#   - ½ Cupful of Butter
#   - 1 Cupful of Milk
#   - Flavoring (to taste)
#
# - **For Pudding Sauce:**
#   - 1 Cupful of Sugar
#   - 3 Heaping Teaspoons of Cornstarch
#   - 1 Pint of Water
#   - Flavoring (to taste)
#
# - **For Salad Dressing:**
#   - 1 Egg
#   - 2 Tablespoons of Sugar
#   - 1 Tablespoon of Flour
#   - ½ Cupful of Vinegar
#   - ½ Cupful of Walnut
#   - ½ Cupful of Milk
#   - 1 Teaspoonful of Mustard
#   - 1 Teaspoonful of Salt
#
# ### Step-by-Step Instructions
# 1. For the egg sauce, cream the sugar and butter together, then add boiling milk and stir constantly until thickened. Let it cool before use.
# 2. For the pudding sauce, mix sugar and cornstarch in a pint of boiling water, then add flavoring.
# 3. For the salad dressing, beat the egg and mix with sugar, flour, vinegar, walnut, milk, mustard, and salt.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Sauce/Dressing
#
# ### Relevant Tags/Metadata
# - Dessert
# - Sauces
# - Pudding
# - Salad Dressing
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Old-Fashioned Candies
#
# ### Ingredients
# #### Chocolate Taffy
# - 1½ Cups of Molasses
# - 1½ Cups of Sugar
# - ½ Cup of Milk
# - 2 Squares of Chocolate
# - 1 Small Teaspoon of Flour
# - Butter (for greasing)
#
# #### Molasses Candy
# - 2 Cups of Molasses
# - ¼ Teaspoon of Soda
# - 2 Teaspoons of Vinegar
# - Butter (for greasing)
#
# ### Instructions
# #### Chocolate Taffy
# 1. Stir the sugar, flour, and grated chocolate into the molasses and milk.
# 2. When hot, add the butter. Boil until it strings.
# 3. Pour into buttered tin. When nearly cold, mark into squares.
#
# #### Molasses Candy
# 1. Put the molasses, vinegar, and butter into a saucepan.
# 2. Boil until it strings when dropped from a spoon.
# 3. When it is brittle when tested in cold water, stir the soda in briskly and pour into a buttered tin.
# 4. When nearly cold, cut into small pieces or sticks and lay on a buttered platter.
#
# ### Cuisine Type
# American
#
# ### Dish Type
# Candy
#
# ### Tags/Metadata
# - Old-fashioned
# - Candy recipes
# - Sweet treats
# - Homemade candy
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.
#
# Here’s the structured information extracted from the recipe image:
#
# ### Recipe Title
# Puddings
#
# ### Ingredients
# #### Bread Pudding
# - 1 Pint of Stale Bread
# - 1 Cupful of Raisins
# - 1 Cupful of Milk
# - 1 Cupful of Sugar
# - 1 Egg
# - 1 Teaspoon of Cinnamon
# - ½ Teaspoon of Salt
#
# #### Steamed Chocolate Pudding
# - ½ Cupful of a Walnut
# - ½ Cupful of Sugar or ½ Cupful of Chocolate
# - 2 Tablespoons of Cocoa
# - ½ Cupful of Milk
# - 1 Egg
# - 1 Teaspoon of Baking Powder
# - Salt to Taste
#
# ### Instructions
# 1. For Bread Pudding:
#    - Pour hot water over the stale bread and let soak until soft.
#    - Then add other ingredients and bake for three hours in a moderate oven.
#    - If eaten cold, serve with hot sauce. If eaten hot, serve with cold sauce.
#
# 2. For Steamed Chocolate Pudding:
#    - Cream together the butter and sugar, then add egg and milk.
#    - Stir in the cocoa, flour, salt, and flavoring.
#    - Steam for an hour and a half, and serve hot.
#
# ### Cuisine Type
# Dessert
#
# ### Dish Type
# Pudding
#
# ### Tags/Metadata
# - Bread Pudding
# - Chocolate Pudding
# - Steamed Dessert
# - Traditional Recipe
#
# This format is suitable for embedding in a Retrieval Augmented Generation (RAG) system.

# %% [markdown]
# # Generative System

# %%
# Define the system prompt
system_prompt3 = f"""
You are highly experienced and expert chef specialized in providing cooking advice.
Your main task is to provide information precise and accurate on the combined content.
You answer diretly to the query using only information from the provided {combined_content}.
If you don't know the answer, just say that you don't know.
Your goal is to help the user and answer the {query}
"""

# %%
# Define function to retrieve a response from the API
def generate_response(query, combined_content, system_prompt):
  response = client.chat.completions.create(
      model = model,
      messages = [
          {"role": "system", "content": system_prompt3}, # Provide system prompt for guidance
          {"role": "user", "content": query}, # Provide the query as user input
          {"role": "assistant", "content": combined_content} # Provide the combined content from the results
      ],
      temperature = 0, # Set temperature to 0 for deterministic output
  )
  return response

# %%
# Get the results from the API
query = "How to make bread?"
combined_content = combined_retrived_content(results)
response = generate_response(query, combined_content, system_prompt3)

# %%
# Display the outcome
get_gpt_response()
# Out:
# I'm sorry, but the provided content does not include a recipe for making bread. If you have a specific bread recipe in mind or need guidance on a particular type of bread, please let me know!

# %%
# Get the results
query = "Get me the best chocolate cake recipe"
combined_content = combined_retrived_content(results)
response = generate_response(query, combined_content, system_prompt3)

# %%
# Display the outcome
get_gpt_response()
# Out:
# I'm sorry, but I don't have a specific chocolate cake recipe available. However, I can provide you with a chocolate sauce recipe if you're interested in making a sauce to accompany a cake. Would you like that?

# %% [markdown]
# # Rag system

# %%
# Build the function for Retrieval-Augmented Generation (RAG)
def rag_system(query, index, metadata, system_prompt, k = 5):
  # Retrieval System: Retrieve relevant results based on the query
  results = query_embeddings(query, index, metadata, k)

  # Content Merge: Combine the retrieved content into a single string
  combined_content = combined_retrived_content(results)

  # Generation: Generate a response based on the query and combined content
  response = generate_response(query, combined_content, system_prompt)

  # Return the generated response
  return response

# %%
# Test the rag system
query1 = "How to make the best chocolate cake?"
response = rag_system(query1, index, metadata, system_prompt3)
get_gpt_response()
# Out:
# The query embedding is [-0.0025930912233889103, -0.03965035080909729, -0.013300711289048195, 0.0075972783379256725, -0.019310662522912025, 0.022375846281647682, 0.00811179168522358, -0.005364072974771261, -0.006425940431654453, 0.03741714358329773, -0.0004070948052685708, 0.007121080067008734, -0.051801618188619614, -0.007602752186357975, 0.0003212285810150206, -0.0403071753680706, 0.02113882638514042, -0.004690826870501041, -0.004521146882325411, -0.015851382166147232, 0
#
# The query vector is [[-0.00259309 -0.03965035 -0.01330071 ...  0.01214032 -0.01021911
#   -0.00113781]]
#
# The stored indices are [22, 26, 28, 66, 27]
#
# The stored distances are [1.196337103843689, 1.236109733581543, 1.246675729751587, 1.2954463958740234, 1.3092255592346191]
# To make the best chocolate cake, you can follow this classic recipe:
#
# ### Recipe Title: Chocolate Cake
#
# ### Ingredients:
# - 1 ¾ cups all-purpose flour
# - 1 ¾ cups granulated sugar
# - ¾ cup unsweetened cocoa powder
# - 1 ½ teaspoons baking powder
# - 1 ½ teaspoons baking soda
# - 1 teaspoon salt
# - 2 large eggs
# - 1 cup whole milk
# - ½ cup vegetable oil
# - 2 teaspoons vanilla extract
# - 1 cup boiling water
#
# ### Instructions:
# 1. **Preheat the Oven**: Preheat your oven to 350°F (175°C). Grease and flour two 9-inch round cake pans.
#
# 2. **Mix Dry Ingredients**: In a large mixing bowl, combine the flour, sugar, cocoa powder, baking powder, baking soda, and salt. Whisk together until well combined.
#
# 3. **Add Wet Ingredients**: Add the eggs, milk, vegetable oil, and vanilla extract to the dry ingredients. Beat on medium speed for about 2 minutes until well blended.
#
# 4. **Incorporate Boiling Water**: Carefully stir in the boiling water (the batter will be thin). Mix until smooth.
#
# 5. **Bake**: Pour the batter evenly into the prepared cake pans. Bake for 30 to 35 minutes, or until a toothpick inserted in the center comes out clean.
#
# 6. **Cool**: Allow the cakes to cool in the pans for 10 minutes, then remove from pans and transfer to wire racks to cool completely.
#
# 7. **Frosting**: Once cooled, frost with your favorite chocolate frosting.
#
# ### Cuisine Type:
# American
#
# ### Dish Type:
# Dessert
#
# ### Relevant Tags/Metadata:
# - Chocolate Cake
# - Baking
# - Dessert
# - Sweet Treat
#
# Enjoy your delicious homemade chocolate cake! If you need any variations or additional tips, feel free to ask!

# %%
# Test with a different query
query2 = "I want something vegan"
response = rag_system(query2, index, metadata, system_prompt3)
get_gpt_response()
# Out:
# The query embedding is [-0.034529902040958405, -0.026633311063051224, -0.017109284177422523, 0.03441669046878815, -0.01732155680656433, -0.008498035371303558, 3.413520607864484e-05, -0.01890653744339943, -0.033737413585186005, 0.02354826219379902, 0.003265481675043702, -0.012984092347323895, 0.0179583802819252, -0.0071642473340034485, 0.036850765347480774, -0.008830597624182701, 0.0097221489995718, -0.011399113573133945, 0.007479120511561632, -0.0183546245098114, -0.023519957438111305, 0.006028581410646439, 0.0375017374753952, -0.006902442779392004, 0.007719697430729866, 0.00817254837602377, -0.022090647369623184, -0.012241133488714695, 0.002090898808091879, 0.018467837944626808, 0.010189151391386986, 0.024496419355273247, -0.005041507072746754, 0.055304449051618576, -0.013684596866369247, -0.003852772992104292, 0.03874707967042923, -0.0019228485180065036, 0.01562336552888155, 0.026958797127008438, -0.047747496515512466, 0.022005736827850342, -0.02418508380651474, 0.001378896413370967, -0.022373678162693977, -0.005908292718231678, 0.0030655902810394764, 0.0056004952639341354, 0.03169958293437958